# %%
import tensorflow as tf
from tensorflow.keras import datasets, models, layers, utils, activations, losses, optimizers, metrics
import numpy as np
import matplotlib.pyplot as plt
import cv2
import os
from glob import glob
from tqdm import tqdm
from sklearn.model_selection import train_test_split
import pandas as pd

# %%
# Define Parameters
num_classes = 3
IMG_SIZE = 224

# %% [markdown]
# #### Data Visualization

# %%
paths = glob('retina-train/*.jpeg')
paths_test = sorted(glob('retina-test/*.jpeg'))
len(paths), len(paths_test)
# Out:
# (2086, 522)

# %%
idx = np.random.randint(0, len(paths), size=1)[0]
path = paths[idx]
# path = 'retina-train/5258_right_2.jpeg'
img = cv2.imread(path)# [:,:,::-1]
plt.imshow(img[:,:,::-1])
print(path)
# Out:
# retina-train/41519_right_0.jpeg

# %%
img_y_cr_cb = cv2.cvtColor(img, cv2.COLOR_BGR2YCrCb)
y, cr, cb = cv2.split(img_y_cr_cb)

# Applying equalize Hist operation on Y channel.
y_eq = cv2.equalizeHist(y)
img_y_cr_cb_eq = cv2.merge((y_eq, cr, cb))
img_rgb_eq = cv2.cvtColor(img_y_cr_cb_eq, cv2.COLOR_YCR_CB2RGB)
plt.imshow(img_rgb_eq)

# %%
all_filenames = [os.path.split(p)[1] for p in paths] # path -> ***.jpeg
print(all_filenames[:3])
all_cls = [int(name.split('.')[0].split('_')[-1]) for name in all_filenames] # ***.jpeg -> 0~4
print(all_cls[:3])
# Out:
# ['24583_left_1.jpeg', '9937_left_0.jpeg', '39291_right_0.jpeg']
# [1, 0, 0]

# %%
# Class distribution
cls, count = np.unique(all_cls, return_counts=True)
plt.bar(cls, count)
# Out:
# <BarContainer object of 3 artists>

# %% [markdown]
# #### Build Transfer Learning Model

# %%
# Method 1: T
# clear graph
tf.keras.backend.clear_session()

base_model = tf.keras.applications.EfficientNetB0(include_top=False, weights='imagenet', input_shape=(IMG_SIZE, IMG_SIZE, 3))
x = base_model.output
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dense(256, activation='relu')(x)
x = layers.Dropout(0.3)(x)
x = layers.Dense(256, activation='relu')(x)
x = layers.Dropout(0.3)(x)
x = layers.Dense(256, activation='relu')(x)
x = layers.Dropout(0.3)(x)
predictions = layers.Dense(3, activation='softmax')(x)

for l in base_model.layers:
    l.trainable = False
model = models.Model(base_model.input, predictions)

# %%
model.summary()

# %% [markdown]
# #### Prepare Data

# %%
# split dataset
path_train, path_val = train_test_split(paths, test_size=0.2)

len(path_train), len(path_val)
# Out:
# (1668, 418)

# %%
def create_dataset(paths, img_size=IMG_SIZE, num_classes=num_classes, test=False):
    num_data = len(paths)
    x_data = np.empty((num_data, img_size, img_size, 3))
    y_data = np.empty((num_data))

    for i, path in enumerate(tqdm(paths)):
        # read image and preprocess
        img = cv2.imread(path)[:,:,::-1]
        img = cv2.resize(img, (img_size, img_size))
        # preprocess by histogram equlization
        img_y_cr_cb = cv2.cvtColor(img, cv2.COLOR_BGR2YCrCb)
        y, cr, cb = cv2.split(img_y_cr_cb)
        # Applying equalize Hist operation on Y channel.
        y_eq = cv2.equalizeHist(y)
        img_y_cr_cb_eq = cv2.merge((y_eq, cr, cb))
        img = cv2.cvtColor(img_y_cr_cb_eq, cv2.COLOR_YCR_CB2RGB)

        # !!!!!!!!! Use model preprocessing function !!!!!!!!!!
        img = tf.keras.applications.efficientnet.preprocess_input(img)
        x_data[i] = img

        if not test:
            # read class label
            filename = os.path.split(path)[1]
            cls = int(filename.split('.')[0].split('_')[-1]) # '38200_left_0.jpeg' -> 0
            y_data[i] = cls
    if not test:
        y_data = utils.to_categorical(y_data, num_classes=num_classes)
        return x_data, y_data
    else:
        return x_data

# %%
x_train, y_train = create_dataset(path_train)
x_val, y_val = create_dataset(path_val)
x_test = create_dataset(paths_test, test=True)
# Out:
# 100%|██████████| 1668/1668 [00:02<00:00, 612.76it/s]
# 100%|██████████| 418/418 [00:00<00:00, 609.39it/s]
# 100%|██████████| 522/522 [00:00<00:00, 623.42it/s]

# %%
x_train.shape, y_train.shape, x_val.shape, y_val.shape
# Out:
# ((1668, 224, 224, 3), (1668, 3), (418, 224, 224, 3), (418, 3))

# %% [markdown]
# #### Training

# %%
model.compile(optimizer='adam', 
              loss=losses.categorical_crossentropy, 
              metrics=[metrics.categorical_accuracy])

# %%
logs = model.fit(x_train, y_train,
                batch_size=32,
                epochs=50,
                validation_data=(x_val, y_val))
# Out:
# Epoch 1/50
# 53/53 [==============================] - 19s 120ms/step - loss: 0.9905 - categorical_accuracy: 0.5326 - val_loss: 0.8591 - val_categorical_accuracy: 0.6268
# Epoch 2/50
# 53/53 [==============================] - 4s 78ms/step - loss: 0.8331 - categorical_accuracy: 0.6238 - val_loss: 0.7619 - val_categorical_accuracy: 0.6579
# Epoch 3/50
# 53/53 [==============================] - 4s 78ms/step - loss: 0.8359 - categorical_accuracy: 0.6290 - val_loss: 0.7324 - val_categorical_accuracy: 0.6722
# Epoch 4/50
# 53/53 [==============================] - 4s 78ms/step - loss: 0.7685 - categorical_accuracy: 0.6440 - val_loss: 0.7173 - val_categorical_accuracy: 0.6794
# Epoch 5/50
# 53/53 [==============================] - 4s 79ms/step - loss: 0.7455 - categorical_accuracy: 0.6598 - val_loss: 0.7103 - val_categorical_accuracy: 0.6818
# Epoch 6/50
# 53/53 [==============================] - 4s 79ms/step - loss: 0.7251 - categorical_accuracy: 0.6800 - val_loss: 0.7161 - val_categorical_accuracy: 0.6962
# Epoch 7/50
# 53/53 [==============================] - 4s 79ms/step - loss: 0.7315 - categorical_accuracy: 0.6667 - val_loss: 0.7263 - val_categorical_accuracy: 0.6818
# Epoch 8/50
# 53/53 [==============================] - 4s 79ms/step - loss: 0.7217 - categorical_accuracy: 0.6639 - val_loss: 0.7157 - val_categorical_accuracy: 0.6938
# Epoch 9/50
# 53/53 [==============================] - 4s 79ms/step - loss: 0.6834 - categorical_accuracy: 0.7015 - val_loss: 0.7580 - val_categorical_accuracy: 0.6722
# Epoch 10/50
# 53/53 [==============================] - 4s 80ms/step - loss: 0.7228 - categorical_accuracy: 0.6643 - val_loss: 0.7121 - val_categorical_accuracy: 0.7033
# Epoch 11/50
# 53/53 [==============================] - 4s 79ms/step - loss: 0.6841 - categorical_accuracy: 0.6918 - val_loss: 0.7145 - val_categorical_accuracy: 0.6914
# Epoch 12/50
# 53/53 [==============================] - 4s 79ms/step - loss: 0.6617 - categorical_accuracy: 0.6954 - val_loss: 0.7013 - val_categorical_accuracy: 0.7057
# Epoch 13/50
# 53/53 [==============================] - 4s 80ms/step - loss: 0.6820 - categorical_accuracy: 0.6894 - val_loss: 0.7234 - val_categorical_accuracy: 0.6842
# Epoch 14/50
# 53/53 [==============================] - 4s 80ms/step - loss: 0.6647 - categorical_accuracy: 0.6798 - val_loss: 0.6973 - val_categorical_accuracy: 0.7129
# Epoch 15/50
# 53/53 [==============================] - 4s 79ms/step - loss: 0.6402 - categorical_accuracy: 0.7082 - val_loss: 0.7303 - val_categorical_accuracy: 0.7129
# Epoch 16/50
# 53/53 [==============================] - 4s 80ms/step - loss: 0.6394 - categorical_accuracy: 0.6995 - val_loss: 0.7007 - val_categorical_accuracy: 0.7010
# Epoch 17/50
# 53/53 [==============================] - 4s 79ms/step - loss: 0.6414 - categorical_accuracy: 0.6989 - val_loss: 0.7659 - val_categorical_accuracy: 0.6842
# Epoch 18/50
# 53/53 [==============================] - 4s 80ms/step - loss: 0.6598 - categorical_accuracy: 0.7011 - val_loss: 0.7099 - val_categorical_accuracy: 0.7081
# Epoch 19/50
# 53/53 [==============================] - 4s 80ms/step - loss: 0.6096 - categorical_accuracy: 0.7235 - val_loss: 0.7541 - val_categorical_accuracy: 0.6794
# Epoch 20/50
# 53/53 [==============================] - 4s 80ms/step - loss: 0.6057 - categorical_accuracy: 0.7193 - val_loss: 0.7339 - val_categorical_accuracy: 0.6914
# Epoch 21/50
# 53/53 [==============================] - 4s 80ms/step - loss: 0.6328 - categorical_accuracy: 0.7120 - val_loss: 0.7276 - val_categorical_accuracy: 0.7033
# Epoch 22/50
# 53/53 [==============================] - 4s 80ms/step - loss: 0.6206 - categorical_accuracy: 0.7008 - val_loss: 0.7374 - val_categorical_accuracy: 0.7105
# Epoch 23/50
# 53/53 [==============================] - 4s 80ms/step - loss: 0.6059 - categorical_accuracy: 0.7172 - val_loss: 0.7192 - val_categorical_accuracy: 0.6986
# Epoch 24/50
# 53/53 [==============================] - 4s 80ms/step - loss: 0.6177 - categorical_accuracy: 0.7163 - val_loss: 0.7636 - val_categorical_accuracy: 0.6818
# Epoch 25/50
# 53/53 [==============================] - 4s 81ms/step - loss: 0.5904 - categorical_accuracy: 0.7330 - val_loss: 0.7527 - val_categorical_accuracy: 0.6890
# Epoch 26/50
# 53/53 [==============================] - 4s 80ms/step - loss: 0.5720 - categorical_accuracy: 0.7398 - val_loss: 0.7430 - val_categorical_accuracy: 0.6914
# Epoch 27/50
# 53/53 [==============================] - 4s 80ms/step - loss: 0.5787 - categorical_accuracy: 0.7376 - val_loss: 0.7566 - val_categorical_accuracy: 0.6794
# Epoch 28/50
# 53/53 [==============================] - 4s 80ms/step - loss: 0.5637 - categorical_accuracy: 0.7423 - val_loss: 0.7321 - val_categorical_accuracy: 0.6962
# Epoch 29/50
# 53/53 [==============================] - 4s 81ms/step - loss: 0.5749 - categorical_accuracy: 0.7408 - val_loss: 0.7318 - val_categorical_accuracy: 0.7081
# Epoch 30/50
# 53/53 [==============================] - 4s 81ms/step - loss: 0.5850 - categorical_accuracy: 0.7396 - val_loss: 0.8005 - val_categorical_accuracy: 0.7177
# Epoch 31/50
# 53/53 [==============================] - 4s 80ms/step - loss: 0.5895 - categorical_accuracy: 0.7212 - val_loss: 0.7537 - val_categorical_accuracy: 0.6890
# Epoch 32/50
# 53/53 [==============================] - 4s 80ms/step - loss: 0.5531 - categorical_accuracy: 0.7435 - val_loss: 0.8123 - val_categorical_accuracy: 0.6818
# Epoch 33/50
# 53/53 [==============================] - 4s 80ms/step - loss: 0.5582 - categorical_accuracy: 0.7526 - val_loss: 0.7884 - val_categorical_accuracy: 0.7010
# Epoch 34/50
# 53/53 [==============================] - 4s 80ms/step - loss: 0.5709 - categorical_accuracy: 0.7442 - val_loss: 0.7624 - val_categorical_accuracy: 0.6842
# Epoch 35/50
# 53/53 [==============================] - 4s 80ms/step - loss: 0.6009 - categorical_accuracy: 0.7209 - val_loss: 0.7399 - val_categorical_accuracy: 0.7081
# Epoch 36/50
# 53/53 [==============================] - 4s 80ms/step - loss: 0.5567 - categorical_accuracy: 0.7508 - val_loss: 0.7784 - val_categorical_accuracy: 0.6890
# Epoch 37/50
# 53/53 [==============================] - 4s 80ms/step - loss: 0.5641 - categorical_accuracy: 0.7416 - val_loss: 0.7985 - val_categorical_accuracy: 0.6651
# Epoch 38/50
# 53/53 [==============================] - 4s 80ms/step - loss: 0.5728 - categorical_accuracy: 0.7316 - val_loss: 0.7643 - val_categorical_accuracy: 0.6890
# Epoch 39/50
# 53/53 [==============================] - 4s 80ms/step - loss: 0.5400 - categorical_accuracy: 0.7651 - val_loss: 0.7902 - val_categorical_accuracy: 0.6986
# Epoch 40/50
# 53/53 [==============================] - 4s 80ms/step - loss: 0.4850 - categorical_accuracy: 0.7695 - val_loss: 0.7929 - val_categorical_accuracy: 0.6938
# Epoch 41/50
# 53/53 [==============================] - 4s 79ms/step - loss: 0.5475 - categorical_accuracy: 0.7622 - val_loss: 0.7891 - val_categorical_accuracy: 0.7081
# Epoch 42/50
# 53/53 [==============================] - 4s 80ms/step - loss: 0.5211 - categorical_accuracy: 0.7542 - val_loss: 0.7976 - val_categorical_accuracy: 0.7129
# Epoch 43/50
# 53/53 [==============================] - 4s 80ms/step - loss: 0.5275 - categorical_accuracy: 0.7599 - val_loss: 0.8129 - val_categorical_accuracy: 0.7129
# Epoch 44/50
# 53/53 [==============================] - 4s 80ms/step - loss: 0.4890 - categorical_accuracy: 0.7812 - val_loss: 0.8753 - val_categorical_accuracy: 0.7057
# Epoch 45/50
# 53/53 [==============================] - 4s 80ms/step - loss: 0.4996 - categorical_accuracy: 0.7661 - val_loss: 0.8530 - val_categorical_accuracy: 0.6459
# Epoch 46/50
# 53/53 [==============================] - 4s 80ms/step - loss: 0.4964 - categorical_accuracy: 0.7773 - val_loss: 0.8542 - val_categorical_accuracy: 0.6818
# Epoch 47/50
# 53/53 [==============================] - 4s 81ms/step - loss: 0.5288 - categorical_accuracy: 0.7727 - val_loss: 0.8378 - val_categorical_accuracy: 0.7033
# Epoch 48/50
# 53/53 [==============================] - 4s 80ms/step - loss: 0.5155 - categorical_accuracy: 0.7658 - val_loss: 0.8395 - val_categorical_accuracy: 0.6914
# Epoch 49/50
# 53/53 [==============================] - 4s 80ms/step - loss: 0.5162 - categorical_accuracy: 0.7568 - val_loss: 0.8611 - val_categorical_accuracy: 0.6579
# Epoch 50/50
# 53/53 [==============================] - 4s 80ms/step - loss: 0.5159 - categorical_accuracy: 0.7729 - val_loss: 0.8174 - val_categorical_accuracy: 0.6938

# %% [markdown]
# #### Make Submission file

# %%
predictions = np.argmax(model.predict(x_test), axis=-1)

df = pd.DataFrame()
df['Id'] = [p.split(os.sep)[-1] for p in paths_test]
df['Category'] = predictions
df.to_csv('submission.csv', index=None)
df
# Out:
#                    Id  Category
# 0     10017_left.jpeg         2
# 1    10031_right.jpeg         0
# 2     10150_left.jpeg         1
# 3    10154_right.jpeg         0
# 4    10440_right.jpeg         0
# ..                ...       ...
# 517    9608_left.jpeg         2
# 518   9673_right.jpeg         0
# 519    9690_left.jpeg         1
# 520   9717_right.jpeg         0
# 521     994_left.jpeg         0
#
# [522 rows x 2 columns]
