# %%
import os
import numpy as np
import cv2
from PIL import Image
import matplotlib.pyplot as plt
from glob import glob
from tqdm.auto import tqdm
import imgaug.augmenters as iaa
import imgaug as ia
from tensorflow.keras import *
import tensorflow.keras.backend as K
from sklearn.model_selection import train_test_split
import pandas as pd

# %% [markdown]
# #### Download data

# %%
# download dataset from https://drive.google.com/file/d/1JILW10sr40CRTLiuA1mf__5GBtMDF9xc/view?usp=sharing
# !gdown --id 1JILW10sr40CRTLiuA1mf__5GBtMDF9xc --output vessel_seg.zip
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1JILW10sr40CRTLiuA1mf__5GBtMDF9xc
# To: /content/vessel_seg.zip
# 29.2MB [00:01, 26.2MB/s]

# %%
# unzip file
# !unzip -q vessel_seg.zip

# %% [markdown]
# #### Data Analysis

# %%
# read img and mask
img_paths = glob('all/train/*.tif')
img_path = np.random.choice(img_paths, size=1)[0]
mask_path = img_path.replace('_training.tif', '_manual1.gif')

print('img path: ', img_path)
print('mask path:',  mask_path)

img = cv2.imread(img_path)[:, :, ::-1]
mask = Image.open(mask_path)
mask = np.array(mask)
# Out:
# img path:  all/train/27_training.tif
# mask path: all/train/27_manual1.gif

# %%
# show image
plt.figure(figsize=(20, 5))
plt.subplot(1,2,1)
plt.imshow(img)
plt.subplot(1,2,2)
plt.imshow(mask)
plt.show()

# %%
img.shape, mask.shape
# Out:
# ((584, 565, 3), (584, 565))

# %% [markdown]
# #### Data processing

# %%
IMG_SIZE = 512
BS = 4

# %%
class DataGenerator(utils.Sequence):
    def __init__(self, img_paths, batch_size, img_size, shuffle=True, mode='train', aug=False):
        self.batch_size = batch_size
        self.shuffle = shuffle
        self.img_size = img_size
        self.mode = mode
        self.img_paths = img_paths
        self.mask_paths = [p.replace('_training.tif', '_manual1.gif') for p in self.img_paths]
        self.aug = aug
        self.indexes = np.arange(len(self.mask_paths))
        self.seq = iaa.Sequential([
            iaa.Fliplr(0.5), # 50% horizontal flip
            iaa.Flipud(0.5),
            iaa.Affine(
                rotate=(90, -90), # random rotate -45 ~ +45 degree
                shear=(-3,3), # random shear -16 ~ +16 degree
                scale={"x": (0.8, 1.2), "y": (0.8, 1.2)} # scale x, y: 80%~120%
            ),
        ])
        self.on_epoch_end()

    def __len__(self):
        return int(np.ceil(len(self.mask_paths) / self.batch_size)) # batches per epoch

    def __getitem__(self, index):
        # Generate indexes of the batch
        idxs = self.indexes[index * self.batch_size:(index + 1) * self.batch_size]
        # Find list of IDs
        batch_img_paths = [self.img_paths[i] for i in idxs]
        batch_mask_paths = [self.mask_paths[i] for i in idxs]

        # Generate data
        X, y = self.__data_generation(batch_img_paths, batch_mask_paths)
        if self.mode != 'test':
            return X, y
        else:
            return X

    def on_epoch_end(self):
        # Updates indexes after each epoch
        if self.shuffle:
            np.random.shuffle(self.indexes)

    def __data_generation(self, img_paths, mask_paths):
        # Generates data containing batch_size samples
        x = np.empty((len(img_paths), self.img_size, self.img_size, 3), dtype=np.float32)
        y = np.empty((len(img_paths), self.img_size, self.img_size, 1), dtype=np.float32)

        for i, (img_path, mask_path) in enumerate(zip(img_paths, mask_paths)):
            img = cv2.imread(img_path)[:, :,::-1]
            img = self.preprocess(img)
            x[i] = img
            if self.mode != 'test':
                mask = np.array(Image.open(mask_path))
                mask = self.preprocess(mask)
                y[i] = np.expand_dims(mask, axis=-1)
        if self.aug:
            x, y = self.seq(images=x, heatmaps=y)
        return x, y

    def preprocess(self, img):
        data = cv2.resize(img, (self.img_size, self.img_size))
        data = data / 255. # normalize to 0~1
        return data

# %%
all_paths = glob('all/train/*.tif')
test_paths = sorted(glob('all/test/*.tif'))
train_paths, val_paths = train_test_split(all_paths, test_size=0.2)

train_gen = DataGenerator(train_paths, BS, IMG_SIZE, shuffle=True, mode='train', aug=True)
val_gen = DataGenerator(val_paths, BS, IMG_SIZE, shuffle=False, mode='val')
test_gen = DataGenerator(test_paths, BS, IMG_SIZE, shuffle=False, mode='test')

# %%
# Check output

batch_x, batch_y = train_gen[0]

batch_i = np.random.choice(len(batch_x))
plt.figure(figsize=(20, 5))
plt.subplot(1,2,1)
plt.imshow(batch_x[batch_i], cmap='gray')
plt.subplot(1,2,2)
plt.imshow(batch_y[batch_i, :, :, 0])
plt.show()

# %% [markdown]
# #### Build model

# %%
def conv_bn(x, filters):
    x = layers.Conv2D(filters=filters, kernel_size=(3,3), padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.ReLU()(x)
    return x

input_layer = layers.Input(shape=(IMG_SIZE, IMG_SIZE, 3))
x = conv_bn(input_layer, 8)
c1 = conv_bn(x, 8)
x = layers.MaxPool2D(strides=(2,2))(c1)
x = conv_bn(x, 16)
c2 = conv_bn(x, 16)
x = layers.MaxPool2D(strides=(2,2))(c2)
x = conv_bn(x, 32)
c3 = conv_bn(x, 32)
x = layers.MaxPool2D(strides=(2,2))(c3)
x = conv_bn(x, 64)
c4 = conv_bn(x, 64)
x = layers.MaxPool2D(strides=(2,2))(c4)
x = conv_bn(x, 128)
c5 = conv_bn(x, 128)
x = layers.MaxPool2D(strides=(2,2))(c5)
x = conv_bn(x, 256)
c6 = conv_bn(x, 256)

x = layers.concatenate([layers.UpSampling2D(size=(2,2))(c6), c5], axis=-1)
x = conv_bn(x, 256)
x = conv_bn(x, 256)
x = layers.concatenate([layers.UpSampling2D(size=(2,2))(x), c4], axis=-1)
x = conv_bn(x, 128)
x = conv_bn(x, 128)
x = layers.concatenate([layers.UpSampling2D(size=(2,2))(x), c3], axis=-1)
x = conv_bn(x, 64)
x = conv_bn(x, 64)
x = layers.concatenate([layers.UpSampling2D(size=(2,2))(x), c2], axis=-1)
x = conv_bn(x, 64)
x = conv_bn(x, 64)
x = layers.concatenate([layers.UpSampling2D(size=(2,2))(x), c1], axis=-1)
x = conv_bn(x, 32)
x = conv_bn(x, 32)

output_layer = layers.Conv2D(filters=1, kernel_size=(1,1), activation='sigmoid')(x)
                                                         
model = models.Model(input_layer, output_layer)

# %%
utils.plot_model(model, show_shapes=True)

# %% [markdown]
# #### Training

# %%
# Customize Dice coefficient
def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + K.epsilon()) / (K.sum(y_true_f) + K.sum(y_pred_f) + K.epsilon())

# %%
model.compile(optimizer=optimizers.Adam(), loss='binary_crossentropy', metrics=[dice_coef])

# %%
weight_saver = callbacks.ModelCheckpoint('seg.h5', monitor='val_loss', save_best_only=True)
earlystop = callbacks.EarlyStopping(monitor='val_loss', patience=100)
lr = callbacks.ReduceLROnPlateau("val_loss", factor=0.2, patience=3, min_lr=0.001)

# %%
logs = model.fit(train_gen,
                 validation_data = val_gen,
                 epochs=1000,
                 callbacks = [weight_saver, earlystop, lr])
# Out:
# Epoch 1/1000
# 4/4 [==============================] - 7s 456ms/step - loss: 0.5926 - dice_coef: 0.1480 - val_loss: 0.6829 - val_dice_coef: 0.1424
# Epoch 2/1000
# 4/4 [==============================] - 1s 281ms/step - loss: 0.4216 - dice_coef: 0.1565 - val_loss: 0.9577 - val_dice_coef: 0.1530
# Epoch 3/1000
# 4/4 [==============================] - 1s 278ms/step - loss: 0.3657 - dice_coef: 0.1529 - val_loss: 3.5510 - val_dice_coef: 0.1587
# Epoch 4/1000
# 4/4 [==============================] - 1s 270ms/step - loss: 0.3428 - dice_coef: 0.1491 - val_loss: 3.2449 - val_dice_coef: 0.1593
# Epoch 5/1000
# 4/4 [==============================] - 1s 284ms/step - loss: 0.3295 - dice_coef: 0.1514 - val_loss: 2.0225 - val_dice_coef: 0.1560
# Epoch 6/1000
# 4/4 [==============================] - 1s 277ms/step - loss: 0.3205 - dice_coef: 0.1571 - val_loss: 0.9079 - val_dice_coef: 0.1448
# Epoch 7/1000
# 4/4 [==============================] - 1s 277ms/step - loss: 0.3231 - dice_coef: 0.1639 - val_loss: 0.5888 - val_dice_coef: 0.1393
# Epoch 8/1000
# 4/4 [==============================] - 1s 282ms/step - loss: 0.2992 - dice_coef: 0.1637 - val_loss: 0.6009 - val_dice_coef: 0.1387
# Epoch 9/1000
# 4/4 [==============================] - 1s 272ms/step - loss: 0.2950 - dice_coef: 0.1844 - val_loss: 0.7926 - val_dice_coef: 0.1481
# Epoch 10/1000
# 4/4 [==============================] - 1s 279ms/step - loss: 0.2858 - dice_coef: 0.2027 - val_loss: 0.6338 - val_dice_coef: 0.1441
# Epoch 11/1000
# 4/4 [==============================] - 1s 273ms/step - loss: 0.2749 - dice_coef: 0.2146 - val_loss: 0.5189 - val_dice_coef: 0.1351
# Epoch 12/1000
# 4/4 [==============================] - 1s 285ms/step - loss: 0.2689 - dice_coef: 0.2350 - val_loss: 0.5232 - val_dice_coef: 0.1361
# Epoch 13/1000
# 4/4 [==============================] - 1s 282ms/step - loss: 0.2466 - dice_coef: 0.2407 - val_loss: 0.5074 - val_dice_coef: 0.1356
# Epoch 14/1000
# 4/4 [==============================] - 1s 283ms/step - loss: 0.2416 - dice_coef: 0.2688 - val_loss: 0.4772 - val_dice_coef: 0.1328
# Epoch 15/1000
# 4/4 [==============================] - 1s 292ms/step - loss: 0.2447 - dice_coef: 0.2983 - val_loss: 0.4422 - val_dice_coef: 0.1275
# Epoch 16/1000
# 4/4 [==============================] - 1s 290ms/step - loss: 0.2211 - dice_coef: 0.3232 - val_loss: 0.4193 - val_dice_coef: 0.1234
# Epoch 17/1000
# 4/4 [==============================] - 1s 291ms/step - loss: 0.2158 - dice_coef: 0.3366 - val_loss: 0.4056 - val_dice_coef: 0.1186
# Epoch 18/1000
# 4/4 [==============================] - 1s 273ms/step - loss: 0.2064 - dice_coef: 0.3504 - val_loss: 0.4081 - val_dice_coef: 0.1215
# Epoch 19/1000
# 4/4 [==============================] - 1s 277ms/step - loss: 0.1950 - dice_coef: 0.3689 - val_loss: 0.3975 - val_dice_coef: 0.1208
# Epoch 20/1000
# 4/4 [==============================] - 1s 278ms/step - loss: 0.1956 - dice_coef: 0.3816 - val_loss: 0.3927 - val_dice_coef: 0.1208
# Epoch 21/1000
# 4/4 [==============================] - 1s 273ms/step - loss: 0.1831 - dice_coef: 0.3898 - val_loss: 0.3866 - val_dice_coef: 0.1203
# Epoch 22/1000
# 4/4 [==============================] - 1s 274ms/step - loss: 0.1836 - dice_coef: 0.4096 - val_loss: 0.3843 - val_dice_coef: 0.1202
# Epoch 23/1000
# 4/4 [==============================] - 1s 277ms/step - loss: 0.1793 - dice_coef: 0.4341 - val_loss: 0.3836 - val_dice_coef: 0.1210
# Epoch 24/1000
# 4/4 [==============================] - 1s 275ms/step - loss: 0.1780 - dice_coef: 0.4341 - val_loss: 0.3756 - val_dice_coef: 0.1161
# Epoch 25/1000
# 4/4 [==============================] - 1s 274ms/step - loss: 0.1677 - dice_coef: 0.4399 - val_loss: 0.3612 - val_dice_coef: 0.1112
# Epoch 26/1000
# 4/4 [==============================] - 1s 277ms/step - loss: 0.1713 - dice_coef: 0.4561 - val_loss: 0.3531 - val_dice_coef: 0.1156
# Epoch 27/1000
# 4/4 [==============================] - 1s 274ms/step - loss: 0.1580 - dice_coef: 0.4514 - val_loss: 0.3390 - val_dice_coef: 0.1117
# Epoch 28/1000
# 4/4 [==============================] - 1s 272ms/step - loss: 0.1683 - dice_coef: 0.4556 - val_loss: 0.3335 - val_dice_coef: 0.0989
# Epoch 29/1000
# 4/4 [==============================] - 1s 273ms/step - loss: 0.1524 - dice_coef: 0.4624 - val_loss: 0.3296 - val_dice_coef: 0.1004
# Epoch 30/1000
# 4/4 [==============================] - 1s 279ms/step - loss: 0.1569 - dice_coef: 0.4688 - val_loss: 0.3266 - val_dice_coef: 0.1005
# Epoch 31/1000
# 4/4 [==============================] - 1s 277ms/step - loss: 0.1663 - dice_coef: 0.4882 - val_loss: 0.3241 - val_dice_coef: 0.0904
# Epoch 32/1000
# 4/4 [==============================] - 1s 275ms/step - loss: 0.1569 - dice_coef: 0.4928 - val_loss: 0.3216 - val_dice_coef: 0.0946
# Epoch 33/1000
# 4/4 [==============================] - 1s 274ms/step - loss: 0.1465 - dice_coef: 0.4988 - val_loss: 0.3094 - val_dice_coef: 0.0858
# Epoch 34/1000
# 4/4 [==============================] - 1s 285ms/step - loss: 0.1456 - dice_coef: 0.4961 - val_loss: 0.3147 - val_dice_coef: 0.1015
# Epoch 35/1000
# 4/4 [==============================] - 1s 278ms/step - loss: 0.1391 - dice_coef: 0.4993 - val_loss: 0.3106 - val_dice_coef: 0.1002
# Epoch 36/1000
# 4/4 [==============================] - 1s 276ms/step - loss: 0.1440 - dice_coef: 0.5094 - val_loss: 0.3072 - val_dice_coef: 0.1094
# Epoch 37/1000
# 4/4 [==============================] - 1s 275ms/step - loss: 0.1543 - dice_coef: 0.5197 - val_loss: 0.3037 - val_dice_coef: 0.1055
# Epoch 38/1000
# 4/4 [==============================] - 1s 280ms/step - loss: 0.1386 - dice_coef: 0.5267 - val_loss: 0.3103 - val_dice_coef: 0.1226
# Epoch 39/1000
# 4/4 [==============================] - 1s 274ms/step - loss: 0.1407 - dice_coef: 0.5261 - val_loss: 0.3218 - val_dice_coef: 0.1422
# Epoch 40/1000
# 4/4 [==============================] - 1s 277ms/step - loss: 0.1346 - dice_coef: 0.5173 - val_loss: 0.3013 - val_dice_coef: 0.1324
# Epoch 41/1000
# 4/4 [==============================] - 1s 281ms/step - loss: 0.1399 - dice_coef: 0.5356 - val_loss: 0.2897 - val_dice_coef: 0.1382
# Epoch 42/1000
# 4/4 [==============================] - 1s 273ms/step - loss: 0.1385 - dice_coef: 0.5326 - val_loss: 0.2859 - val_dice_coef: 0.1344
# Epoch 43/1000
# 4/4 [==============================] - 1s 274ms/step - loss: 0.1386 - dice_coef: 0.5385 - val_loss: 0.2964 - val_dice_coef: 0.0913
# Epoch 44/1000
# 4/4 [==============================] - 1s 280ms/step - loss: 0.1353 - dice_coef: 0.5385 - val_loss: 0.2881 - val_dice_coef: 0.1073
# Epoch 45/1000
# 4/4 [==============================] - 1s 281ms/step - loss: 0.1382 - dice_coef: 0.5361 - val_loss: 0.2886 - val_dice_coef: 0.0974
# Epoch 46/1000
# 4/4 [==============================] - 1s 280ms/step - loss: 0.1331 - dice_coef: 0.5439 - val_loss: 0.2916 - val_dice_coef: 0.0923
# Epoch 47/1000
# 4/4 [==============================] - 1s 280ms/step - loss: 0.1323 - dice_coef: 0.5514 - val_loss: 0.2706 - val_dice_coef: 0.1284
# Epoch 48/1000
# 4/4 [==============================] - 1s 287ms/step - loss: 0.1362 - dice_coef: 0.5573 - val_loss: 0.2621 - val_dice_coef: 0.1428
# Epoch 49/1000
# 4/4 [==============================] - 1s 290ms/step - loss: 0.1319 - dice_coef: 0.5634 - val_loss: 0.2627 - val_dice_coef: 0.1388
# Epoch 50/1000
# 4/4 [==============================] - 1s 281ms/step - loss: 0.1299 - dice_coef: 0.5604 - val_loss: 0.2608 - val_dice_coef: 0.1409
# Epoch 51/1000
# 4/4 [==============================] - 1s 285ms/step - loss: 0.1258 - dice_coef: 0.5645 - val_loss: 0.2574 - val_dice_coef: 0.1610
# Epoch 52/1000
# 4/4 [==============================] - 1s 283ms/step - loss: 0.1234 - dice_coef: 0.5646 - val_loss: 0.2491 - val_dice_coef: 0.1740
# Epoch 53/1000
# 4/4 [==============================] - 1s 282ms/step - loss: 0.1256 - dice_coef: 0.5737 - val_loss: 0.2487 - val_dice_coef: 0.1705
# Epoch 54/1000
# 4/4 [==============================] - 1s 283ms/step - loss: 0.1290 - dice_coef: 0.5645 - val_loss: 0.2435 - val_dice_coef: 0.1753
# Epoch 55/1000
# 4/4 [==============================] - 1s 286ms/step - loss: 0.1204 - dice_coef: 0.5792 - val_loss: 0.2404 - val_dice_coef: 0.1887
# Epoch 56/1000
# 4/4 [==============================] - 1s 280ms/step - loss: 0.1267 - dice_coef: 0.5757 - val_loss: 0.2427 - val_dice_coef: 0.1736
# Epoch 57/1000
# 4/4 [==============================] - 1s 279ms/step - loss: 0.1251 - dice_coef: 0.5793 - val_loss: 0.2427 - val_dice_coef: 0.1743
# Epoch 58/1000
# 4/4 [==============================] - 1s 287ms/step - loss: 0.1205 - dice_coef: 0.5769 - val_loss: 0.2369 - val_dice_coef: 0.1874
# Epoch 59/1000
# 4/4 [==============================] - 1s 278ms/step - loss: 0.1226 - dice_coef: 0.5899 - val_loss: 0.2322 - val_dice_coef: 0.1943
# Epoch 60/1000
# 4/4 [==============================] - 1s 288ms/step - loss: 0.1183 - dice_coef: 0.5766 - val_loss: 0.2302 - val_dice_coef: 0.2040
# Epoch 61/1000
# 4/4 [==============================] - 1s 278ms/step - loss: 0.1253 - dice_coef: 0.5899 - val_loss: 0.2169 - val_dice_coef: 0.2322
# Epoch 62/1000
# 4/4 [==============================] - 1s 278ms/step - loss: 0.1131 - dice_coef: 0.5906 - val_loss: 0.2150 - val_dice_coef: 0.2286
# Epoch 63/1000
# 4/4 [==============================] - 1s 279ms/step - loss: 0.1207 - dice_coef: 0.5842 - val_loss: 0.2134 - val_dice_coef: 0.2330
# Epoch 64/1000
# 4/4 [==============================] - 1s 279ms/step - loss: 0.1173 - dice_coef: 0.5896 - val_loss: 0.2152 - val_dice_coef: 0.2333
# Epoch 65/1000
# 4/4 [==============================] - 1s 277ms/step - loss: 0.1248 - dice_coef: 0.5950 - val_loss: 0.2133 - val_dice_coef: 0.2402
# Epoch 66/1000
# 4/4 [==============================] - 1s 277ms/step - loss: 0.1217 - dice_coef: 0.6042 - val_loss: 0.2064 - val_dice_coef: 0.2573
# Epoch 67/1000
# 4/4 [==============================] - 1s 280ms/step - loss: 0.1182 - dice_coef: 0.5948 - val_loss: 0.2064 - val_dice_coef: 0.2653
# Epoch 68/1000
# 4/4 [==============================] - 1s 279ms/step - loss: 0.1155 - dice_coef: 0.6054 - val_loss: 0.2045 - val_dice_coef: 0.2783
# Epoch 69/1000
# 4/4 [==============================] - 1s 275ms/step - loss: 0.1157 - dice_coef: 0.6022 - val_loss: 0.1957 - val_dice_coef: 0.3066
# Epoch 70/1000
# 4/4 [==============================] - 1s 277ms/step - loss: 0.1136 - dice_coef: 0.6071 - val_loss: 0.1860 - val_dice_coef: 0.3330
# Epoch 71/1000
# 4/4 [==============================] - 1s 278ms/step - loss: 0.1158 - dice_coef: 0.6125 - val_loss: 0.1839 - val_dice_coef: 0.3318
# Epoch 72/1000
# 4/4 [==============================] - 1s 284ms/step - loss: 0.1106 - dice_coef: 0.5995 - val_loss: 0.1775 - val_dice_coef: 0.3478
# Epoch 73/1000
# 4/4 [==============================] - 1s 281ms/step - loss: 0.1114 - dice_coef: 0.6139 - val_loss: 0.1740 - val_dice_coef: 0.3545
# Epoch 74/1000
# 4/4 [==============================] - 1s 277ms/step - loss: 0.1127 - dice_coef: 0.6110 - val_loss: 0.1798 - val_dice_coef: 0.3501
# Epoch 75/1000
# 4/4 [==============================] - 1s 275ms/step - loss: 0.1200 - dice_coef: 0.6172 - val_loss: 0.1845 - val_dice_coef: 0.3470
# Epoch 76/1000
# 4/4 [==============================] - 1s 278ms/step - loss: 0.1089 - dice_coef: 0.6149 - val_loss: 0.1790 - val_dice_coef: 0.3608
# Epoch 77/1000
# 4/4 [==============================] - 1s 279ms/step - loss: 0.1188 - dice_coef: 0.6133 - val_loss: 0.1960 - val_dice_coef: 0.3167
# Epoch 78/1000
# 4/4 [==============================] - 1s 276ms/step - loss: 0.1117 - dice_coef: 0.6196 - val_loss: 0.1911 - val_dice_coef: 0.3264
# Epoch 79/1000
# 4/4 [==============================] - 1s 280ms/step - loss: 0.1175 - dice_coef: 0.6172 - val_loss: 0.1663 - val_dice_coef: 0.3983
# Epoch 80/1000
# 4/4 [==============================] - 1s 280ms/step - loss: 0.1103 - dice_coef: 0.6183 - val_loss: 0.1579 - val_dice_coef: 0.4139
# Epoch 81/1000
# 4/4 [==============================] - 1s 282ms/step - loss: 0.1183 - dice_coef: 0.6132 - val_loss: 0.1612 - val_dice_coef: 0.4131
# Epoch 82/1000
# 4/4 [==============================] - 1s 274ms/step - loss: 0.1170 - dice_coef: 0.6240 - val_loss: 0.1574 - val_dice_coef: 0.4236
# Epoch 83/1000
# 4/4 [==============================] - 1s 284ms/step - loss: 0.1067 - dice_coef: 0.6204 - val_loss: 0.1474 - val_dice_coef: 0.4460
# Epoch 84/1000
# 4/4 [==============================] - 1s 283ms/step - loss: 0.1120 - dice_coef: 0.6212 - val_loss: 0.1496 - val_dice_coef: 0.4413
# Epoch 85/1000
# 4/4 [==============================] - 1s 276ms/step - loss: 0.1214 - dice_coef: 0.6167 - val_loss: 0.1651 - val_dice_coef: 0.4061
# Epoch 86/1000
# 4/4 [==============================] - 1s 279ms/step - loss: 0.1169 - dice_coef: 0.6218 - val_loss: 0.1567 - val_dice_coef: 0.4407
# Epoch 87/1000
# 4/4 [==============================] - 1s 278ms/step - loss: 0.1078 - dice_coef: 0.6305 - val_loss: 0.1497 - val_dice_coef: 0.4540
# Epoch 88/1000
# 4/4 [==============================] - 1s 279ms/step - loss: 0.1057 - dice_coef: 0.6247 - val_loss: 0.1406 - val_dice_coef: 0.4863
# Epoch 89/1000
# 4/4 [==============================] - 1s 280ms/step - loss: 0.1077 - dice_coef: 0.6235 - val_loss: 0.1426 - val_dice_coef: 0.4947
# Epoch 90/1000
# 4/4 [==============================] - 1s 278ms/step - loss: 0.1032 - dice_coef: 0.6187 - val_loss: 0.1474 - val_dice_coef: 0.4915
# Epoch 91/1000
# 4/4 [==============================] - 1s 281ms/step - loss: 0.1105 - dice_coef: 0.6347 - val_loss: 0.1494 - val_dice_coef: 0.5009
# Epoch 92/1000
# 4/4 [==============================] - 1s 278ms/step - loss: 0.1050 - dice_coef: 0.6332 - val_loss: 0.1608 - val_dice_coef: 0.4607
# Epoch 93/1000
# 4/4 [==============================] - 1s 282ms/step - loss: 0.1103 - dice_coef: 0.6226 - val_loss: 0.1497 - val_dice_coef: 0.4950
# Epoch 94/1000
# 4/4 [==============================] - 1s 285ms/step - loss: 0.1097 - dice_coef: 0.6347 - val_loss: 0.1361 - val_dice_coef: 0.5261
# Epoch 95/1000
# 4/4 [==============================] - 1s 291ms/step - loss: 0.1145 - dice_coef: 0.6316 - val_loss: 0.1400 - val_dice_coef: 0.5055
# Epoch 96/1000
# 4/4 [==============================] - 1s 280ms/step - loss: 0.1068 - dice_coef: 0.6272 - val_loss: 0.1332 - val_dice_coef: 0.5131
# Epoch 97/1000
# 4/4 [==============================] - 1s 286ms/step - loss: 0.1059 - dice_coef: 0.6249 - val_loss: 0.1221 - val_dice_coef: 0.5443
# Epoch 98/1000
# 4/4 [==============================] - 1s 283ms/step - loss: 0.1134 - dice_coef: 0.6307 - val_loss: 0.1264 - val_dice_coef: 0.5406
# Epoch 99/1000
# 4/4 [==============================] - 1s 283ms/step - loss: 0.1062 - dice_coef: 0.6273 - val_loss: 0.1219 - val_dice_coef: 0.5546
# Epoch 100/1000
# 4/4 [==============================] - 1s 290ms/step - loss: 0.1020 - dice_coef: 0.6401 - val_loss: 0.1228 - val_dice_coef: 0.5591
# Epoch 101/1000
# 4/4 [==============================] - 1s 280ms/step - loss: 0.1010 - dice_coef: 0.6341 - val_loss: 0.1194 - val_dice_coef: 0.5610
# Epoch 102/1000
# 4/4 [==============================] - 1s 282ms/step - loss: 0.1033 - dice_coef: 0.6324 - val_loss: 0.1151 - val_dice_coef: 0.5790
# Epoch 103/1000
# 4/4 [==============================] - 1s 293ms/step - loss: 0.1073 - dice_coef: 0.6351 - val_loss: 0.1209 - val_dice_coef: 0.5586
# Epoch 104/1000
# 4/4 [==============================] - 1s 282ms/step - loss: 0.1055 - dice_coef: 0.6368 - val_loss: 0.1210 - val_dice_coef: 0.5652
# Epoch 105/1000
# 4/4 [==============================] - 1s 283ms/step - loss: 0.1040 - dice_coef: 0.6454 - val_loss: 0.1197 - val_dice_coef: 0.5613
# Epoch 106/1000
# 4/4 [==============================] - 1s 285ms/step - loss: 0.1088 - dice_coef: 0.6432 - val_loss: 0.1251 - val_dice_coef: 0.5409
# Epoch 107/1000
# 4/4 [==============================] - 1s 283ms/step - loss: 0.1056 - dice_coef: 0.6434 - val_loss: 0.1245 - val_dice_coef: 0.5569
# Epoch 108/1000
# 4/4 [==============================] - 1s 283ms/step - loss: 0.1079 - dice_coef: 0.6498 - val_loss: 0.1209 - val_dice_coef: 0.5690
# Epoch 109/1000
# 4/4 [==============================] - 1s 279ms/step - loss: 0.1032 - dice_coef: 0.6445 - val_loss: 0.1255 - val_dice_coef: 0.5500
# Epoch 110/1000
# 4/4 [==============================] - 1s 284ms/step - loss: 0.1087 - dice_coef: 0.6444 - val_loss: 0.1190 - val_dice_coef: 0.5717
# Epoch 111/1000
# 4/4 [==============================] - 1s 278ms/step - loss: 0.1053 - dice_coef: 0.6490 - val_loss: 0.1218 - val_dice_coef: 0.5685
# Epoch 112/1000
# 4/4 [==============================] - 1s 280ms/step - loss: 0.1069 - dice_coef: 0.6426 - val_loss: 0.1236 - val_dice_coef: 0.5607
# Epoch 113/1000
# 4/4 [==============================] - 1s 283ms/step - loss: 0.1021 - dice_coef: 0.6454 - val_loss: 0.1110 - val_dice_coef: 0.5995
# Epoch 114/1000
# 4/4 [==============================] - 1s 280ms/step - loss: 0.1101 - dice_coef: 0.6481 - val_loss: 0.1140 - val_dice_coef: 0.5897
# Epoch 115/1000
# 4/4 [==============================] - 1s 285ms/step - loss: 0.1043 - dice_coef: 0.6446 - val_loss: 0.1106 - val_dice_coef: 0.6036
# Epoch 116/1000
# 4/4 [==============================] - 1s 280ms/step - loss: 0.1044 - dice_coef: 0.6376 - val_loss: 0.1147 - val_dice_coef: 0.6026
# Epoch 117/1000
# 4/4 [==============================] - 1s 280ms/step - loss: 0.1097 - dice_coef: 0.6402 - val_loss: 0.1138 - val_dice_coef: 0.6103
# Epoch 118/1000
# 4/4 [==============================] - 1s 279ms/step - loss: 0.1034 - dice_coef: 0.6424 - val_loss: 0.1123 - val_dice_coef: 0.6095
# Epoch 119/1000
# 4/4 [==============================] - 1s 281ms/step - loss: 0.1042 - dice_coef: 0.6430 - val_loss: 0.1181 - val_dice_coef: 0.5907
# Epoch 120/1000
# 4/4 [==============================] - 1s 282ms/step - loss: 0.1042 - dice_coef: 0.6380 - val_loss: 0.1192 - val_dice_coef: 0.5786
# Epoch 121/1000
# 4/4 [==============================] - 1s 281ms/step - loss: 0.1025 - dice_coef: 0.6505 - val_loss: 0.1169 - val_dice_coef: 0.5932
# Epoch 122/1000
# 4/4 [==============================] - 1s 281ms/step - loss: 0.1074 - dice_coef: 0.6504 - val_loss: 0.1186 - val_dice_coef: 0.5762
# Epoch 123/1000
# 4/4 [==============================] - 1s 283ms/step - loss: 0.1034 - dice_coef: 0.6522 - val_loss: 0.1283 - val_dice_coef: 0.5487
# Epoch 124/1000
# 4/4 [==============================] - 1s 280ms/step - loss: 0.1048 - dice_coef: 0.6469 - val_loss: 0.1286 - val_dice_coef: 0.5458
# Epoch 125/1000
# 4/4 [==============================] - 1s 278ms/step - loss: 0.1057 - dice_coef: 0.6452 - val_loss: 0.1174 - val_dice_coef: 0.5818
# Epoch 126/1000
# 4/4 [==============================] - 1s 281ms/step - loss: 0.0965 - dice_coef: 0.6487 - val_loss: 0.1097 - val_dice_coef: 0.6027
# Epoch 127/1000
# 4/4 [==============================] - 1s 279ms/step - loss: 0.1033 - dice_coef: 0.6502 - val_loss: 0.1068 - val_dice_coef: 0.6127
# Epoch 128/1000
# 4/4 [==============================] - 1s 281ms/step - loss: 0.1090 - dice_coef: 0.6534 - val_loss: 0.1051 - val_dice_coef: 0.6217
# Epoch 129/1000
# 4/4 [==============================] - 1s 283ms/step - loss: 0.1061 - dice_coef: 0.6579 - val_loss: 0.1011 - val_dice_coef: 0.6387
# Epoch 130/1000
# 4/4 [==============================] - 1s 281ms/step - loss: 0.1057 - dice_coef: 0.6539 - val_loss: 0.1013 - val_dice_coef: 0.6281
# Epoch 131/1000
# 4/4 [==============================] - 1s 277ms/step - loss: 0.1013 - dice_coef: 0.6476 - val_loss: 0.0986 - val_dice_coef: 0.6392
# Epoch 132/1000
# 4/4 [==============================] - 1s 284ms/step - loss: 0.1007 - dice_coef: 0.6551 - val_loss: 0.0990 - val_dice_coef: 0.6450
# Epoch 133/1000
# 4/4 [==============================] - 1s 282ms/step - loss: 0.1052 - dice_coef: 0.6560 - val_loss: 0.0998 - val_dice_coef: 0.6345
# Epoch 134/1000
# 4/4 [==============================] - 1s 286ms/step - loss: 0.0992 - dice_coef: 0.6538 - val_loss: 0.1004 - val_dice_coef: 0.6317
# Epoch 135/1000
# 4/4 [==============================] - 1s 283ms/step - loss: 0.1067 - dice_coef: 0.6495 - val_loss: 0.0984 - val_dice_coef: 0.6408
# Epoch 136/1000
# 4/4 [==============================] - 1s 280ms/step - loss: 0.0993 - dice_coef: 0.6511 - val_loss: 0.1023 - val_dice_coef: 0.6232
# Epoch 137/1000
# 4/4 [==============================] - 1s 278ms/step - loss: 0.1059 - dice_coef: 0.6505 - val_loss: 0.1018 - val_dice_coef: 0.6277
# Epoch 138/1000
# 4/4 [==============================] - 1s 279ms/step - loss: 0.0993 - dice_coef: 0.6654 - val_loss: 0.1016 - val_dice_coef: 0.6343
# Epoch 139/1000
# 4/4 [==============================] - 1s 278ms/step - loss: 0.0932 - dice_coef: 0.6558 - val_loss: 0.1022 - val_dice_coef: 0.6171
# Epoch 140/1000
# 4/4 [==============================] - 1s 285ms/step - loss: 0.1006 - dice_coef: 0.6547 - val_loss: 0.1044 - val_dice_coef: 0.6206
# Epoch 141/1000
# 4/4 [==============================] - 1s 289ms/step - loss: 0.1033 - dice_coef: 0.6583 - val_loss: 0.1122 - val_dice_coef: 0.6013
# Epoch 142/1000
# 4/4 [==============================] - 1s 286ms/step - loss: 0.1032 - dice_coef: 0.6654 - val_loss: 0.1038 - val_dice_coef: 0.6240
# Epoch 143/1000
# 4/4 [==============================] - 1s 290ms/step - loss: 0.1009 - dice_coef: 0.6663 - val_loss: 0.0998 - val_dice_coef: 0.6265
# Epoch 144/1000
# 4/4 [==============================] - 1s 283ms/step - loss: 0.1020 - dice_coef: 0.6591 - val_loss: 0.0975 - val_dice_coef: 0.6401
# Epoch 145/1000
# 4/4 [==============================] - 1s 288ms/step - loss: 0.0995 - dice_coef: 0.6609 - val_loss: 0.1006 - val_dice_coef: 0.6274
# Epoch 146/1000
# 4/4 [==============================] - 1s 288ms/step - loss: 0.0975 - dice_coef: 0.6611 - val_loss: 0.0994 - val_dice_coef: 0.6365
# Epoch 147/1000
# 4/4 [==============================] - 1s 285ms/step - loss: 0.1004 - dice_coef: 0.6618 - val_loss: 0.0967 - val_dice_coef: 0.6461
# Epoch 148/1000
# 4/4 [==============================] - 1s 286ms/step - loss: 0.0926 - dice_coef: 0.6600 - val_loss: 0.0964 - val_dice_coef: 0.6494
# Epoch 149/1000
# 4/4 [==============================] - 1s 292ms/step - loss: 0.0885 - dice_coef: 0.6610 - val_loss: 0.0970 - val_dice_coef: 0.6436
# Epoch 150/1000
# 4/4 [==============================] - 1s 286ms/step - loss: 0.0988 - dice_coef: 0.6633 - val_loss: 0.0963 - val_dice_coef: 0.6488
# Epoch 151/1000
# 4/4 [==============================] - 1s 288ms/step - loss: 0.0943 - dice_coef: 0.6618 - val_loss: 0.0971 - val_dice_coef: 0.6518
# Epoch 152/1000
# 4/4 [==============================] - 1s 283ms/step - loss: 0.0954 - dice_coef: 0.6651 - val_loss: 0.0957 - val_dice_coef: 0.6633
# Epoch 153/1000
# 4/4 [==============================] - 1s 282ms/step - loss: 0.0997 - dice_coef: 0.6656 - val_loss: 0.0962 - val_dice_coef: 0.6622
# Epoch 154/1000
# 4/4 [==============================] - 1s 282ms/step - loss: 0.1067 - dice_coef: 0.6594 - val_loss: 0.0977 - val_dice_coef: 0.6490
# Epoch 155/1000
# 4/4 [==============================] - 1s 286ms/step - loss: 0.0986 - dice_coef: 0.6564 - val_loss: 0.0965 - val_dice_coef: 0.6539
# Epoch 156/1000
# 4/4 [==============================] - 1s 287ms/step - loss: 0.0999 - dice_coef: 0.6621 - val_loss: 0.1028 - val_dice_coef: 0.6319
# Epoch 157/1000
# 4/4 [==============================] - 1s 283ms/step - loss: 0.1009 - dice_coef: 0.6503 - val_loss: 0.0971 - val_dice_coef: 0.6704
# Epoch 158/1000
# 4/4 [==============================] - 1s 284ms/step - loss: 0.1057 - dice_coef: 0.6631 - val_loss: 0.0965 - val_dice_coef: 0.6717
# Epoch 159/1000
# 4/4 [==============================] - 1s 279ms/step - loss: 0.0989 - dice_coef: 0.6612 - val_loss: 0.0970 - val_dice_coef: 0.6755
# Epoch 160/1000
# 4/4 [==============================] - 1s 281ms/step - loss: 0.0944 - dice_coef: 0.6630 - val_loss: 0.0984 - val_dice_coef: 0.6611
# Epoch 161/1000
# 4/4 [==============================] - 1s 283ms/step - loss: 0.0999 - dice_coef: 0.6574 - val_loss: 0.0997 - val_dice_coef: 0.6320
# Epoch 162/1000
# 4/4 [==============================] - 1s 283ms/step - loss: 0.0996 - dice_coef: 0.6533 - val_loss: 0.0998 - val_dice_coef: 0.6379
# Epoch 163/1000
# 4/4 [==============================] - 1s 284ms/step - loss: 0.1028 - dice_coef: 0.6604 - val_loss: 0.0996 - val_dice_coef: 0.6431
# Epoch 164/1000
# 4/4 [==============================] - 1s 284ms/step - loss: 0.1077 - dice_coef: 0.6638 - val_loss: 0.0976 - val_dice_coef: 0.6540
# Epoch 165/1000
# 4/4 [==============================] - 1s 285ms/step - loss: 0.0940 - dice_coef: 0.6641 - val_loss: 0.1011 - val_dice_coef: 0.6321
# Epoch 166/1000
# 4/4 [==============================] - 1s 289ms/step - loss: 0.1115 - dice_coef: 0.6548 - val_loss: 0.1000 - val_dice_coef: 0.6519
# Epoch 167/1000
# 4/4 [==============================] - 1s 286ms/step - loss: 0.1056 - dice_coef: 0.6709 - val_loss: 0.0993 - val_dice_coef: 0.6514
# Epoch 168/1000
# 4/4 [==============================] - 1s 286ms/step - loss: 0.0950 - dice_coef: 0.6620 - val_loss: 0.1012 - val_dice_coef: 0.6393
# Epoch 169/1000
# 4/4 [==============================] - 1s 290ms/step - loss: 0.0997 - dice_coef: 0.6600 - val_loss: 0.1056 - val_dice_coef: 0.6340
# Epoch 170/1000
# 4/4 [==============================] - 1s 287ms/step - loss: 0.1004 - dice_coef: 0.6699 - val_loss: 0.0987 - val_dice_coef: 0.6526
# Epoch 171/1000
# 4/4 [==============================] - 1s 296ms/step - loss: 0.1002 - dice_coef: 0.6677 - val_loss: 0.0982 - val_dice_coef: 0.6460
# Epoch 172/1000
# 4/4 [==============================] - 1s 283ms/step - loss: 0.0976 - dice_coef: 0.6640 - val_loss: 0.0970 - val_dice_coef: 0.6541
# Epoch 173/1000
# 4/4 [==============================] - 1s 285ms/step - loss: 0.0947 - dice_coef: 0.6677 - val_loss: 0.0974 - val_dice_coef: 0.6524
# Epoch 174/1000
# 4/4 [==============================] - 1s 285ms/step - loss: 0.0914 - dice_coef: 0.6649 - val_loss: 0.0976 - val_dice_coef: 0.6537
# Epoch 175/1000
# 4/4 [==============================] - 1s 286ms/step - loss: 0.0996 - dice_coef: 0.6721 - val_loss: 0.0980 - val_dice_coef: 0.6498
# Epoch 176/1000
# 4/4 [==============================] - 1s 289ms/step - loss: 0.1044 - dice_coef: 0.6723 - val_loss: 0.0980 - val_dice_coef: 0.6445
# Epoch 177/1000
# 4/4 [==============================] - 1s 284ms/step - loss: 0.1006 - dice_coef: 0.6700 - val_loss: 0.0963 - val_dice_coef: 0.6578
# Epoch 178/1000
# 4/4 [==============================] - 1s 281ms/step - loss: 0.0907 - dice_coef: 0.6702 - val_loss: 0.0982 - val_dice_coef: 0.6439
# Epoch 179/1000
# 4/4 [==============================] - 1s 289ms/step - loss: 0.1018 - dice_coef: 0.6591 - val_loss: 0.0978 - val_dice_coef: 0.6465
# Epoch 180/1000
# 4/4 [==============================] - 1s 287ms/step - loss: 0.0985 - dice_coef: 0.6725 - val_loss: 0.0972 - val_dice_coef: 0.6443
# Epoch 181/1000
# 4/4 [==============================] - 1s 285ms/step - loss: 0.0902 - dice_coef: 0.6736 - val_loss: 0.0966 - val_dice_coef: 0.6473
# Epoch 182/1000
# 4/4 [==============================] - 1s 288ms/step - loss: 0.0980 - dice_coef: 0.6711 - val_loss: 0.0965 - val_dice_coef: 0.6519
# Epoch 183/1000
# 4/4 [==============================] - 1s 292ms/step - loss: 0.0959 - dice_coef: 0.6711 - val_loss: 0.0953 - val_dice_coef: 0.6480
# Epoch 184/1000
# 4/4 [==============================] - 1s 284ms/step - loss: 0.1012 - dice_coef: 0.6692 - val_loss: 0.0955 - val_dice_coef: 0.6468
# Epoch 185/1000
# 4/4 [==============================] - 1s 282ms/step - loss: 0.0992 - dice_coef: 0.6710 - val_loss: 0.0988 - val_dice_coef: 0.6378
# Epoch 186/1000
# 4/4 [==============================] - 1s 288ms/step - loss: 0.0979 - dice_coef: 0.6712 - val_loss: 0.0992 - val_dice_coef: 0.6315
# Epoch 187/1000
# 4/4 [==============================] - 1s 284ms/step - loss: 0.0981 - dice_coef: 0.6698 - val_loss: 0.0985 - val_dice_coef: 0.6316
# Epoch 188/1000
# 4/4 [==============================] - 1s 283ms/step - loss: 0.0994 - dice_coef: 0.6693 - val_loss: 0.1007 - val_dice_coef: 0.6357
# Epoch 189/1000
# 4/4 [==============================] - 1s 284ms/step - loss: 0.1028 - dice_coef: 0.6738 - val_loss: 0.0980 - val_dice_coef: 0.6437
# Epoch 190/1000
# 4/4 [==============================] - 1s 286ms/step - loss: 0.0942 - dice_coef: 0.6658 - val_loss: 0.0995 - val_dice_coef: 0.6308
# Epoch 191/1000
# 4/4 [==============================] - 1s 285ms/step - loss: 0.0981 - dice_coef: 0.6691 - val_loss: 0.0969 - val_dice_coef: 0.6600
# Epoch 192/1000
# 4/4 [==============================] - 1s 284ms/step - loss: 0.0969 - dice_coef: 0.6764 - val_loss: 0.0971 - val_dice_coef: 0.6420
# Epoch 193/1000
# 4/4 [==============================] - 1s 282ms/step - loss: 0.0959 - dice_coef: 0.6743 - val_loss: 0.0980 - val_dice_coef: 0.6418
# Epoch 194/1000
# 4/4 [==============================] - 1s 284ms/step - loss: 0.0971 - dice_coef: 0.6769 - val_loss: 0.0987 - val_dice_coef: 0.6443
# Epoch 195/1000
# 4/4 [==============================] - 1s 286ms/step - loss: 0.1000 - dice_coef: 0.6674 - val_loss: 0.1061 - val_dice_coef: 0.6181
# Epoch 196/1000
# 4/4 [==============================] - 1s 286ms/step - loss: 0.0918 - dice_coef: 0.6664 - val_loss: 0.0997 - val_dice_coef: 0.6416
# Epoch 197/1000
# 4/4 [==============================] - 1s 290ms/step - loss: 0.0895 - dice_coef: 0.6719 - val_loss: 0.0974 - val_dice_coef: 0.6424
# Epoch 198/1000
# 4/4 [==============================] - 1s 289ms/step - loss: 0.0931 - dice_coef: 0.6770 - val_loss: 0.0982 - val_dice_coef: 0.6362
# Epoch 199/1000
# 4/4 [==============================] - 1s 282ms/step - loss: 0.0953 - dice_coef: 0.6736 - val_loss: 0.0974 - val_dice_coef: 0.6468
# Epoch 200/1000
# 4/4 [==============================] - 1s 279ms/step - loss: 0.0914 - dice_coef: 0.6793 - val_loss: 0.0968 - val_dice_coef: 0.6438
# Epoch 201/1000
# 4/4 [==============================] - 1s 281ms/step - loss: 0.1018 - dice_coef: 0.6676 - val_loss: 0.0990 - val_dice_coef: 0.6275
# Epoch 202/1000
# 4/4 [==============================] - 1s 286ms/step - loss: 0.1072 - dice_coef: 0.6718 - val_loss: 0.0959 - val_dice_coef: 0.6522
# Epoch 203/1000
# 4/4 [==============================] - 1s 281ms/step - loss: 0.1004 - dice_coef: 0.6812 - val_loss: 0.0972 - val_dice_coef: 0.6391
# Epoch 204/1000
# 4/4 [==============================] - 1s 285ms/step - loss: 0.0943 - dice_coef: 0.6724 - val_loss: 0.0965 - val_dice_coef: 0.6414
# Epoch 205/1000
# 4/4 [==============================] - 1s 283ms/step - loss: 0.0895 - dice_coef: 0.6756 - val_loss: 0.0956 - val_dice_coef: 0.6547
# Epoch 206/1000
# 4/4 [==============================] - 1s 281ms/step - loss: 0.0985 - dice_coef: 0.6713 - val_loss: 0.0977 - val_dice_coef: 0.6390
# Epoch 207/1000
# 4/4 [==============================] - 1s 292ms/step - loss: 0.0980 - dice_coef: 0.6689 - val_loss: 0.0934 - val_dice_coef: 0.6663
# Epoch 208/1000
# 4/4 [==============================] - 1s 287ms/step - loss: 0.1010 - dice_coef: 0.6797 - val_loss: 0.0949 - val_dice_coef: 0.6653
# Epoch 209/1000
# 4/4 [==============================] - 1s 285ms/step - loss: 0.0987 - dice_coef: 0.6767 - val_loss: 0.0957 - val_dice_coef: 0.6604
# Epoch 210/1000
# 4/4 [==============================] - 1s 289ms/step - loss: 0.0943 - dice_coef: 0.6784 - val_loss: 0.0928 - val_dice_coef: 0.6581
# Epoch 211/1000
# 4/4 [==============================] - 1s 290ms/step - loss: 0.1019 - dice_coef: 0.6718 - val_loss: 0.0977 - val_dice_coef: 0.6441
# Epoch 212/1000
# 4/4 [==============================] - 1s 283ms/step - loss: 0.0939 - dice_coef: 0.6700 - val_loss: 0.0981 - val_dice_coef: 0.6383
# Epoch 213/1000
# 4/4 [==============================] - 1s 286ms/step - loss: 0.0940 - dice_coef: 0.6716 - val_loss: 0.0983 - val_dice_coef: 0.6352
# Epoch 214/1000
# 4/4 [==============================] - 1s 281ms/step - loss: 0.0967 - dice_coef: 0.6753 - val_loss: 0.1058 - val_dice_coef: 0.6360
# Epoch 215/1000
# 4/4 [==============================] - 1s 284ms/step - loss: 0.0960 - dice_coef: 0.6713 - val_loss: 0.0987 - val_dice_coef: 0.6563
# Epoch 216/1000
# 4/4 [==============================] - 1s 291ms/step - loss: 0.0980 - dice_coef: 0.6742 - val_loss: 0.0980 - val_dice_coef: 0.6496
# Epoch 217/1000
# 4/4 [==============================] - 1s 283ms/step - loss: 0.0957 - dice_coef: 0.6771 - val_loss: 0.0996 - val_dice_coef: 0.6483
# Epoch 218/1000
# 4/4 [==============================] - 1s 287ms/step - loss: 0.0954 - dice_coef: 0.6786 - val_loss: 0.0979 - val_dice_coef: 0.6402
# Epoch 219/1000
# 4/4 [==============================] - 1s 290ms/step - loss: 0.0997 - dice_coef: 0.6762 - val_loss: 0.0946 - val_dice_coef: 0.6473
# Epoch 220/1000
# 4/4 [==============================] - 1s 287ms/step - loss: 0.0963 - dice_coef: 0.6776 - val_loss: 0.0941 - val_dice_coef: 0.6529
# Epoch 221/1000
# 4/4 [==============================] - 1s 289ms/step - loss: 0.0910 - dice_coef: 0.6772 - val_loss: 0.0955 - val_dice_coef: 0.6463
# Epoch 222/1000
# 4/4 [==============================] - 1s 290ms/step - loss: 0.0952 - dice_coef: 0.6769 - val_loss: 0.0964 - val_dice_coef: 0.6393
# Epoch 223/1000
# 4/4 [==============================] - 1s 290ms/step - loss: 0.0968 - dice_coef: 0.6810 - val_loss: 0.0930 - val_dice_coef: 0.6571
# Epoch 224/1000
# 4/4 [==============================] - 1s 289ms/step - loss: 0.0982 - dice_coef: 0.6800 - val_loss: 0.0955 - val_dice_coef: 0.6416
# Epoch 225/1000
# 4/4 [==============================] - 1s 288ms/step - loss: 0.0978 - dice_coef: 0.6793 - val_loss: 0.0960 - val_dice_coef: 0.6434
# Epoch 226/1000
# 4/4 [==============================] - 1s 290ms/step - loss: 0.0925 - dice_coef: 0.6794 - val_loss: 0.0951 - val_dice_coef: 0.6423
# Epoch 227/1000
# 4/4 [==============================] - 1s 290ms/step - loss: 0.0930 - dice_coef: 0.6775 - val_loss: 0.0933 - val_dice_coef: 0.6621
# Epoch 228/1000
# 4/4 [==============================] - 1s 289ms/step - loss: 0.1013 - dice_coef: 0.6805 - val_loss: 0.0925 - val_dice_coef: 0.6674
# Epoch 229/1000
# 4/4 [==============================] - 1s 293ms/step - loss: 0.0918 - dice_coef: 0.6816 - val_loss: 0.0957 - val_dice_coef: 0.6484
# Epoch 230/1000
# 4/4 [==============================] - 1s 290ms/step - loss: 0.0952 - dice_coef: 0.6727 - val_loss: 0.0917 - val_dice_coef: 0.6642
# Epoch 231/1000
# 4/4 [==============================] - 1s 288ms/step - loss: 0.0990 - dice_coef: 0.6784 - val_loss: 0.0910 - val_dice_coef: 0.6808
# Epoch 232/1000
# 4/4 [==============================] - 1s 292ms/step - loss: 0.0942 - dice_coef: 0.6813 - val_loss: 0.0929 - val_dice_coef: 0.6650
# Epoch 233/1000
# 4/4 [==============================] - 1s 285ms/step - loss: 0.0948 - dice_coef: 0.6772 - val_loss: 0.0924 - val_dice_coef: 0.6673
# Epoch 234/1000
# 4/4 [==============================] - 1s 292ms/step - loss: 0.0906 - dice_coef: 0.6786 - val_loss: 0.0929 - val_dice_coef: 0.6705
# Epoch 235/1000
# 4/4 [==============================] - 1s 290ms/step - loss: 0.0899 - dice_coef: 0.6808 - val_loss: 0.0957 - val_dice_coef: 0.6583
# Epoch 236/1000
# 4/4 [==============================] - 1s 283ms/step - loss: 0.0998 - dice_coef: 0.6780 - val_loss: 0.0965 - val_dice_coef: 0.6541
# Epoch 237/1000
# 4/4 [==============================] - 1s 286ms/step - loss: 0.0964 - dice_coef: 0.6807 - val_loss: 0.0947 - val_dice_coef: 0.6555
# Epoch 238/1000
# 4/4 [==============================] - 1s 288ms/step - loss: 0.0972 - dice_coef: 0.6851 - val_loss: 0.0943 - val_dice_coef: 0.6614
# Epoch 239/1000
# 4/4 [==============================] - 1s 289ms/step - loss: 0.0926 - dice_coef: 0.6858 - val_loss: 0.0950 - val_dice_coef: 0.6661
# Epoch 240/1000
# 4/4 [==============================] - 1s 287ms/step - loss: 0.0945 - dice_coef: 0.6827 - val_loss: 0.0975 - val_dice_coef: 0.6604
# Epoch 241/1000
# 4/4 [==============================] - 1s 286ms/step - loss: 0.0972 - dice_coef: 0.6777 - val_loss: 0.0993 - val_dice_coef: 0.6492
# Epoch 242/1000
# 4/4 [==============================] - 1s 287ms/step - loss: 0.0962 - dice_coef: 0.6783 - val_loss: 0.0989 - val_dice_coef: 0.6530
# Epoch 243/1000
# 4/4 [==============================] - 1s 289ms/step - loss: 0.0917 - dice_coef: 0.6864 - val_loss: 0.0984 - val_dice_coef: 0.6435
# Epoch 244/1000
# 4/4 [==============================] - 1s 286ms/step - loss: 0.0973 - dice_coef: 0.6833 - val_loss: 0.0981 - val_dice_coef: 0.6401
# Epoch 245/1000
# 4/4 [==============================] - 1s 285ms/step - loss: 0.0963 - dice_coef: 0.6843 - val_loss: 0.0980 - val_dice_coef: 0.6397
# Epoch 246/1000
# 4/4 [==============================] - 1s 287ms/step - loss: 0.0935 - dice_coef: 0.6817 - val_loss: 0.0969 - val_dice_coef: 0.6453
# Epoch 247/1000
# 4/4 [==============================] - 1s 289ms/step - loss: 0.0932 - dice_coef: 0.6835 - val_loss: 0.0956 - val_dice_coef: 0.6511
# Epoch 248/1000
# 4/4 [==============================] - 1s 287ms/step - loss: 0.0946 - dice_coef: 0.6848 - val_loss: 0.0987 - val_dice_coef: 0.6342
# Epoch 249/1000
# 4/4 [==============================] - 1s 289ms/step - loss: 0.0962 - dice_coef: 0.6844 - val_loss: 0.0976 - val_dice_coef: 0.6467
# Epoch 250/1000
# 4/4 [==============================] - 1s 284ms/step - loss: 0.0919 - dice_coef: 0.6849 - val_loss: 0.0963 - val_dice_coef: 0.6496
# Epoch 251/1000
# 4/4 [==============================] - 1s 288ms/step - loss: 0.0932 - dice_coef: 0.6802 - val_loss: 0.0957 - val_dice_coef: 0.6446
# Epoch 252/1000
# 4/4 [==============================] - 1s 285ms/step - loss: 0.0916 - dice_coef: 0.6809 - val_loss: 0.0960 - val_dice_coef: 0.6533
# Epoch 253/1000
# 4/4 [==============================] - 1s 289ms/step - loss: 0.0960 - dice_coef: 0.6849 - val_loss: 0.0970 - val_dice_coef: 0.6472
# Epoch 254/1000
# 4/4 [==============================] - 1s 287ms/step - loss: 0.0940 - dice_coef: 0.6820 - val_loss: 0.0940 - val_dice_coef: 0.6598
# Epoch 255/1000
# 4/4 [==============================] - 1s 289ms/step - loss: 0.0928 - dice_coef: 0.6841 - val_loss: 0.0964 - val_dice_coef: 0.6410
# Epoch 256/1000
# 4/4 [==============================] - 1s 289ms/step - loss: 0.0941 - dice_coef: 0.6789 - val_loss: 0.1014 - val_dice_coef: 0.6251
# Epoch 257/1000
# 4/4 [==============================] - 1s 290ms/step - loss: 0.0911 - dice_coef: 0.6844 - val_loss: 0.0982 - val_dice_coef: 0.6424
# Epoch 258/1000
# 4/4 [==============================] - 1s 287ms/step - loss: 0.0969 - dice_coef: 0.6851 - val_loss: 0.0990 - val_dice_coef: 0.6307
# Epoch 259/1000
# 4/4 [==============================] - 1s 288ms/step - loss: 0.0941 - dice_coef: 0.6816 - val_loss: 0.1001 - val_dice_coef: 0.6226
# Epoch 260/1000
# 4/4 [==============================] - 1s 288ms/step - loss: 0.0972 - dice_coef: 0.6816 - val_loss: 0.0939 - val_dice_coef: 0.6581
# Epoch 261/1000
# 4/4 [==============================] - 1s 288ms/step - loss: 0.0909 - dice_coef: 0.6867 - val_loss: 0.0935 - val_dice_coef: 0.6600
# Epoch 262/1000
# 4/4 [==============================] - 1s 287ms/step - loss: 0.0937 - dice_coef: 0.6866 - val_loss: 0.0952 - val_dice_coef: 0.6539
# Epoch 263/1000
# 4/4 [==============================] - 1s 284ms/step - loss: 0.0955 - dice_coef: 0.6829 - val_loss: 0.0931 - val_dice_coef: 0.6674
# Epoch 264/1000
# 4/4 [==============================] - 1s 289ms/step - loss: 0.0910 - dice_coef: 0.6826 - val_loss: 0.0910 - val_dice_coef: 0.6775
# Epoch 265/1000
# 4/4 [==============================] - 1s 285ms/step - loss: 0.0881 - dice_coef: 0.6793 - val_loss: 0.0934 - val_dice_coef: 0.6661
# Epoch 266/1000
# 4/4 [==============================] - 1s 288ms/step - loss: 0.0875 - dice_coef: 0.6823 - val_loss: 0.0967 - val_dice_coef: 0.6665
# Epoch 267/1000
# 4/4 [==============================] - 1s 287ms/step - loss: 0.0955 - dice_coef: 0.6808 - val_loss: 0.0956 - val_dice_coef: 0.6511
# Epoch 268/1000
# 4/4 [==============================] - 1s 284ms/step - loss: 0.0919 - dice_coef: 0.6836 - val_loss: 0.0924 - val_dice_coef: 0.6758
# Epoch 269/1000
# 4/4 [==============================] - 1s 294ms/step - loss: 0.0989 - dice_coef: 0.6886 - val_loss: 0.0946 - val_dice_coef: 0.6673
# Epoch 270/1000
# 4/4 [==============================] - 1s 290ms/step - loss: 0.0969 - dice_coef: 0.6853 - val_loss: 0.0929 - val_dice_coef: 0.6572
# Epoch 271/1000
# 4/4 [==============================] - 1s 293ms/step - loss: 0.0925 - dice_coef: 0.6840 - val_loss: 0.0939 - val_dice_coef: 0.6616
# Epoch 272/1000
# 4/4 [==============================] - 1s 294ms/step - loss: 0.0947 - dice_coef: 0.6836 - val_loss: 0.0960 - val_dice_coef: 0.6584
# Epoch 273/1000
# 4/4 [==============================] - 1s 295ms/step - loss: 0.0923 - dice_coef: 0.6842 - val_loss: 0.0932 - val_dice_coef: 0.6726
# Epoch 274/1000
# 4/4 [==============================] - 1s 291ms/step - loss: 0.0925 - dice_coef: 0.6878 - val_loss: 0.0929 - val_dice_coef: 0.6555
# Epoch 275/1000
# 4/4 [==============================] - 1s 288ms/step - loss: 0.0895 - dice_coef: 0.6883 - val_loss: 0.0923 - val_dice_coef: 0.6568
# Epoch 276/1000
# 4/4 [==============================] - 1s 289ms/step - loss: 0.0940 - dice_coef: 0.6824 - val_loss: 0.0936 - val_dice_coef: 0.6536
# Epoch 277/1000
# 4/4 [==============================] - 1s 290ms/step - loss: 0.0925 - dice_coef: 0.6832 - val_loss: 0.0927 - val_dice_coef: 0.6628
# Epoch 278/1000
# 4/4 [==============================] - 1s 293ms/step - loss: 0.0909 - dice_coef: 0.6825 - val_loss: 0.0933 - val_dice_coef: 0.6571
# Epoch 279/1000
# 4/4 [==============================] - 1s 292ms/step - loss: 0.0938 - dice_coef: 0.6831 - val_loss: 0.0943 - val_dice_coef: 0.6556
# Epoch 280/1000
# 4/4 [==============================] - 1s 292ms/step - loss: 0.0927 - dice_coef: 0.6821 - val_loss: 0.0943 - val_dice_coef: 0.6579
# Epoch 281/1000
# 4/4 [==============================] - 1s 291ms/step - loss: 0.0945 - dice_coef: 0.6857 - val_loss: 0.0931 - val_dice_coef: 0.6553
# Epoch 282/1000
# 4/4 [==============================] - 1s 295ms/step - loss: 0.0944 - dice_coef: 0.6887 - val_loss: 0.0941 - val_dice_coef: 0.6527
# Epoch 283/1000
# 4/4 [==============================] - 1s 289ms/step - loss: 0.0876 - dice_coef: 0.6921 - val_loss: 0.0920 - val_dice_coef: 0.6630
# Epoch 284/1000
# 4/4 [==============================] - 1s 288ms/step - loss: 0.0927 - dice_coef: 0.6877 - val_loss: 0.0926 - val_dice_coef: 0.6560
# Epoch 285/1000
# 4/4 [==============================] - 1s 288ms/step - loss: 0.0888 - dice_coef: 0.6830 - val_loss: 0.0927 - val_dice_coef: 0.6590
# Epoch 286/1000
# 4/4 [==============================] - 1s 284ms/step - loss: 0.0910 - dice_coef: 0.6861 - val_loss: 0.0932 - val_dice_coef: 0.6585
# Epoch 287/1000
# 4/4 [==============================] - 1s 285ms/step - loss: 0.0951 - dice_coef: 0.6847 - val_loss: 0.0972 - val_dice_coef: 0.6424
# Epoch 288/1000
# 4/4 [==============================] - 1s 292ms/step - loss: 0.0958 - dice_coef: 0.6846 - val_loss: 0.0930 - val_dice_coef: 0.6654
# Epoch 289/1000
# 4/4 [==============================] - 1s 287ms/step - loss: 0.0905 - dice_coef: 0.6870 - val_loss: 0.0937 - val_dice_coef: 0.6687
# Epoch 290/1000
# 4/4 [==============================] - 1s 287ms/step - loss: 0.0913 - dice_coef: 0.6887 - val_loss: 0.0938 - val_dice_coef: 0.6657
# Epoch 291/1000
# 4/4 [==============================] - 1s 287ms/step - loss: 0.0946 - dice_coef: 0.6840 - val_loss: 0.0937 - val_dice_coef: 0.6683
# Epoch 292/1000
# 4/4 [==============================] - 1s 290ms/step - loss: 0.0906 - dice_coef: 0.6876 - val_loss: 0.0965 - val_dice_coef: 0.6583
# Epoch 293/1000
# 4/4 [==============================] - 1s 286ms/step - loss: 0.0956 - dice_coef: 0.6888 - val_loss: 0.0915 - val_dice_coef: 0.6880
# Epoch 294/1000
# 4/4 [==============================] - 1s 285ms/step - loss: 0.0878 - dice_coef: 0.6862 - val_loss: 0.0926 - val_dice_coef: 0.6711
# Epoch 295/1000
# 4/4 [==============================] - 1s 287ms/step - loss: 0.0934 - dice_coef: 0.6848 - val_loss: 0.0922 - val_dice_coef: 0.6699
# Epoch 296/1000
# 4/4 [==============================] - 1s 284ms/step - loss: 0.0908 - dice_coef: 0.6918 - val_loss: 0.0920 - val_dice_coef: 0.6684
# Epoch 297/1000
# 4/4 [==============================] - 1s 290ms/step - loss: 0.0893 - dice_coef: 0.6950 - val_loss: 0.0934 - val_dice_coef: 0.6568
# Epoch 298/1000
# 4/4 [==============================] - 1s 288ms/step - loss: 0.0932 - dice_coef: 0.6910 - val_loss: 0.0903 - val_dice_coef: 0.6794
# Epoch 299/1000
# 4/4 [==============================] - 1s 288ms/step - loss: 0.0944 - dice_coef: 0.6814 - val_loss: 0.0919 - val_dice_coef: 0.6593
# Epoch 300/1000
# 4/4 [==============================] - 1s 288ms/step - loss: 0.0977 - dice_coef: 0.6875 - val_loss: 0.0920 - val_dice_coef: 0.6590
# Epoch 301/1000
# 4/4 [==============================] - 1s 291ms/step - loss: 0.0947 - dice_coef: 0.6897 - val_loss: 0.1033 - val_dice_coef: 0.6220
# Epoch 302/1000
# 4/4 [==============================] - 1s 289ms/step - loss: 0.0962 - dice_coef: 0.6861 - val_loss: 0.0970 - val_dice_coef: 0.6418
# Epoch 303/1000
# 4/4 [==============================] - 1s 291ms/step - loss: 0.0874 - dice_coef: 0.6892 - val_loss: 0.0915 - val_dice_coef: 0.6625
# Epoch 304/1000
# 4/4 [==============================] - 1s 288ms/step - loss: 0.0926 - dice_coef: 0.6920 - val_loss: 0.0924 - val_dice_coef: 0.6546
# Epoch 305/1000
# 4/4 [==============================] - 1s 285ms/step - loss: 0.0865 - dice_coef: 0.6903 - val_loss: 0.0898 - val_dice_coef: 0.6676
# Epoch 306/1000
# 4/4 [==============================] - 1s 290ms/step - loss: 0.0874 - dice_coef: 0.6917 - val_loss: 0.0920 - val_dice_coef: 0.6609
# Epoch 307/1000
# 4/4 [==============================] - 1s 291ms/step - loss: 0.0914 - dice_coef: 0.6899 - val_loss: 0.0922 - val_dice_coef: 0.6573
# Epoch 308/1000
# 4/4 [==============================] - 1s 285ms/step - loss: 0.0920 - dice_coef: 0.6886 - val_loss: 0.0928 - val_dice_coef: 0.6624
# Epoch 309/1000
# 4/4 [==============================] - 1s 286ms/step - loss: 0.0906 - dice_coef: 0.6908 - val_loss: 0.0914 - val_dice_coef: 0.6719
# Epoch 310/1000
# 4/4 [==============================] - 1s 286ms/step - loss: 0.0906 - dice_coef: 0.6911 - val_loss: 0.0951 - val_dice_coef: 0.6628
# Epoch 311/1000
# 4/4 [==============================] - 1s 284ms/step - loss: 0.0946 - dice_coef: 0.6904 - val_loss: 0.0940 - val_dice_coef: 0.6716
# Epoch 312/1000
# 4/4 [==============================] - 1s 281ms/step - loss: 0.0949 - dice_coef: 0.6915 - val_loss: 0.0968 - val_dice_coef: 0.6596
# Epoch 313/1000
# 4/4 [==============================] - 1s 282ms/step - loss: 0.0888 - dice_coef: 0.6871 - val_loss: 0.0944 - val_dice_coef: 0.6570
# Epoch 314/1000
# 4/4 [==============================] - 1s 287ms/step - loss: 0.0892 - dice_coef: 0.6927 - val_loss: 0.0899 - val_dice_coef: 0.6740
# Epoch 315/1000
# 4/4 [==============================] - 1s 287ms/step - loss: 0.0893 - dice_coef: 0.6930 - val_loss: 0.0922 - val_dice_coef: 0.6637
# Epoch 316/1000
# 4/4 [==============================] - 1s 286ms/step - loss: 0.0886 - dice_coef: 0.6904 - val_loss: 0.0931 - val_dice_coef: 0.6587
# Epoch 317/1000
# 4/4 [==============================] - 1s 287ms/step - loss: 0.0903 - dice_coef: 0.6930 - val_loss: 0.0923 - val_dice_coef: 0.6667
# Epoch 318/1000
# 4/4 [==============================] - 1s 288ms/step - loss: 0.0916 - dice_coef: 0.6942 - val_loss: 0.0910 - val_dice_coef: 0.6677
# Epoch 319/1000
# 4/4 [==============================] - 1s 287ms/step - loss: 0.0909 - dice_coef: 0.6921 - val_loss: 0.0930 - val_dice_coef: 0.6573
# Epoch 320/1000
# 4/4 [==============================] - 1s 289ms/step - loss: 0.0929 - dice_coef: 0.6867 - val_loss: 0.0989 - val_dice_coef: 0.6296
# Epoch 321/1000
# 4/4 [==============================] - 1s 290ms/step - loss: 0.0922 - dice_coef: 0.6854 - val_loss: 0.0961 - val_dice_coef: 0.6519
# Epoch 322/1000
# 4/4 [==============================] - 1s 294ms/step - loss: 0.0902 - dice_coef: 0.6907 - val_loss: 0.0906 - val_dice_coef: 0.6670
# Epoch 323/1000
# 4/4 [==============================] - 1s 288ms/step - loss: 0.0948 - dice_coef: 0.6859 - val_loss: 0.0914 - val_dice_coef: 0.6626
# Epoch 324/1000
# 4/4 [==============================] - 1s 289ms/step - loss: 0.0894 - dice_coef: 0.6867 - val_loss: 0.0947 - val_dice_coef: 0.6500
# Epoch 325/1000
# 4/4 [==============================] - 1s 287ms/step - loss: 0.0902 - dice_coef: 0.6908 - val_loss: 0.0911 - val_dice_coef: 0.6766
# Epoch 326/1000
# 4/4 [==============================] - 1s 291ms/step - loss: 0.0915 - dice_coef: 0.6938 - val_loss: 0.0913 - val_dice_coef: 0.6754
# Epoch 327/1000
# 4/4 [==============================] - 1s 294ms/step - loss: 0.0845 - dice_coef: 0.6934 - val_loss: 0.0893 - val_dice_coef: 0.6800
# Epoch 328/1000
# 4/4 [==============================] - 1s 289ms/step - loss: 0.0939 - dice_coef: 0.6908 - val_loss: 0.0888 - val_dice_coef: 0.6785
# Epoch 329/1000
# 4/4 [==============================] - 1s 298ms/step - loss: 0.0866 - dice_coef: 0.6888 - val_loss: 0.0895 - val_dice_coef: 0.6788
# Epoch 330/1000
# ...
# Epoch 566/1000
# 4/4 [==============================] - 1s 295ms/step - loss: 0.0848 - dice_coef: 0.7063 - val_loss: 0.0866 - val_dice_coef: 0.7020
# Epoch 567/1000
# 4/4 [==============================] - 1s 294ms/step - loss: 0.0870 - dice_coef: 0.7065 - val_loss: 0.0878 - val_dice_coef: 0.6998
# Epoch 568/1000
# 4/4 [==============================] - 1s 287ms/step - loss: 0.0859 - dice_coef: 0.7059 - val_loss: 0.0858 - val_dice_coef: 0.6938
# Epoch 569/1000
# 4/4 [==============================] - 1s 296ms/step - loss: 0.0820 - dice_coef: 0.7103 - val_loss: 0.0880 - val_dice_coef: 0.6938
# Epoch 570/1000
# 4/4 [==============================] - 1s 289ms/step - loss: 0.0865 - dice_coef: 0.7078 - val_loss: 0.0884 - val_dice_coef: 0.6886
# Epoch 571/1000
# 4/4 [==============================] - 1s 293ms/step - loss: 0.0864 - dice_coef: 0.7087 - val_loss: 0.0885 - val_dice_coef: 0.6840
# Epoch 572/1000
# 4/4 [==============================] - 1s 288ms/step - loss: 0.0813 - dice_coef: 0.7056 - val_loss: 0.0889 - val_dice_coef: 0.6843
# Epoch 573/1000
# 4/4 [==============================] - 1s 290ms/step - loss: 0.0831 - dice_coef: 0.7052 - val_loss: 0.0860 - val_dice_coef: 0.7008
# Epoch 574/1000
# 4/4 [==============================] - 1s 290ms/step - loss: 0.0798 - dice_coef: 0.7026 - val_loss: 0.0857 - val_dice_coef: 0.7000
# Epoch 575/1000
# 4/4 [==============================] - 1s 285ms/step - loss: 0.0876 - dice_coef: 0.7060 - val_loss: 0.0874 - val_dice_coef: 0.7016
# Epoch 576/1000
# 4/4 [==============================] - 1s 289ms/step - loss: 0.0859 - dice_coef: 0.7108 - val_loss: 0.0860 - val_dice_coef: 0.6973
# Epoch 577/1000
# 4/4 [==============================] - 1s 289ms/step - loss: 0.0825 - dice_coef: 0.7071 - val_loss: 0.0866 - val_dice_coef: 0.7048
# Epoch 578/1000
# 4/4 [==============================] - 1s 288ms/step - loss: 0.0825 - dice_coef: 0.7094 - val_loss: 0.0893 - val_dice_coef: 0.6936
# Epoch 579/1000
# 4/4 [==============================] - 1s 292ms/step - loss: 0.0811 - dice_coef: 0.7068 - val_loss: 0.0880 - val_dice_coef: 0.6837
# Epoch 580/1000
# 4/4 [==============================] - 1s 292ms/step - loss: 0.0845 - dice_coef: 0.7095 - val_loss: 0.0865 - val_dice_coef: 0.6839
# Epoch 581/1000
# 4/4 [==============================] - 1s 288ms/step - loss: 0.0893 - dice_coef: 0.7072 - val_loss: 0.0867 - val_dice_coef: 0.6889
# Epoch 582/1000
# 4/4 [==============================] - 1s 292ms/step - loss: 0.0886 - dice_coef: 0.7088 - val_loss: 0.0874 - val_dice_coef: 0.6881
# Epoch 583/1000
# 4/4 [==============================] - 1s 286ms/step - loss: 0.0811 - dice_coef: 0.7064 - val_loss: 0.0868 - val_dice_coef: 0.6887
# Epoch 584/1000
# 4/4 [==============================] - 1s 290ms/step - loss: 0.0805 - dice_coef: 0.7079 - val_loss: 0.0863 - val_dice_coef: 0.6914
# Epoch 585/1000
# 4/4 [==============================] - 1s 286ms/step - loss: 0.0797 - dice_coef: 0.7073 - val_loss: 0.0867 - val_dice_coef: 0.6853
# Epoch 586/1000
# 4/4 [==============================] - 1s 290ms/step - loss: 0.0836 - dice_coef: 0.7064 - val_loss: 0.0878 - val_dice_coef: 0.6819
# Epoch 587/1000
# 4/4 [==============================] - 1s 284ms/step - loss: 0.0846 - dice_coef: 0.7066 - val_loss: 0.0863 - val_dice_coef: 0.6942
# Epoch 588/1000
# 4/4 [==============================] - 1s 290ms/step - loss: 0.0801 - dice_coef: 0.7111 - val_loss: 0.0863 - val_dice_coef: 0.6869
# Epoch 589/1000
# 4/4 [==============================] - 1s 292ms/step - loss: 0.0890 - dice_coef: 0.7065 - val_loss: 0.0904 - val_dice_coef: 0.6764
# Epoch 590/1000
# 4/4 [==============================] - 1s 290ms/step - loss: 0.0880 - dice_coef: 0.7096 - val_loss: 0.0887 - val_dice_coef: 0.6827
# Epoch 591/1000
# 4/4 [==============================] - 1s 286ms/step - loss: 0.0910 - dice_coef: 0.7032 - val_loss: 0.0884 - val_dice_coef: 0.6746
# Epoch 592/1000
# 4/4 [==============================] - 1s 289ms/step - loss: 0.0858 - dice_coef: 0.7074 - val_loss: 0.0893 - val_dice_coef: 0.6714
# Epoch 593/1000
# 4/4 [==============================] - 1s 289ms/step - loss: 0.0860 - dice_coef: 0.7071 - val_loss: 0.0889 - val_dice_coef: 0.6789
# Epoch 594/1000
# 4/4 [==============================] - 1s 291ms/step - loss: 0.0868 - dice_coef: 0.7025 - val_loss: 0.0899 - val_dice_coef: 0.6675
# Epoch 595/1000
# 4/4 [==============================] - 1s 288ms/step - loss: 0.0860 - dice_coef: 0.7038 - val_loss: 0.0879 - val_dice_coef: 0.6921
# Epoch 596/1000
# 4/4 [==============================] - 1s 289ms/step - loss: 0.0858 - dice_coef: 0.7084 - val_loss: 0.0871 - val_dice_coef: 0.6944
# Epoch 597/1000
# 4/4 [==============================] - 1s 294ms/step - loss: 0.0843 - dice_coef: 0.7020 - val_loss: 0.0870 - val_dice_coef: 0.6907
# Epoch 598/1000
# 4/4 [==============================] - 1s 288ms/step - loss: 0.0884 - dice_coef: 0.7053 - val_loss: 0.0876 - val_dice_coef: 0.6870
# Epoch 599/1000
# 4/4 [==============================] - 1s 291ms/step - loss: 0.0833 - dice_coef: 0.7072 - val_loss: 0.0883 - val_dice_coef: 0.6868
# Epoch 600/1000
# 4/4 [==============================] - 1s 294ms/step - loss: 0.0880 - dice_coef: 0.7061 - val_loss: 0.0892 - val_dice_coef: 0.6898
# Epoch 601/1000
# 4/4 [==============================] - 1s 287ms/step - loss: 0.0842 - dice_coef: 0.7079 - val_loss: 0.0894 - val_dice_coef: 0.6766
# Epoch 602/1000
# 4/4 [==============================] - 1s 294ms/step - loss: 0.0826 - dice_coef: 0.7051 - val_loss: 0.0888 - val_dice_coef: 0.6985
# Epoch 603/1000
# 4/4 [==============================] - 1s 293ms/step - loss: 0.0827 - dice_coef: 0.7049 - val_loss: 0.0871 - val_dice_coef: 0.7005
# Epoch 604/1000
# 4/4 [==============================] - 1s 294ms/step - loss: 0.0827 - dice_coef: 0.7047 - val_loss: 0.0870 - val_dice_coef: 0.6990
# Epoch 605/1000
# 4/4 [==============================] - 1s 292ms/step - loss: 0.0855 - dice_coef: 0.7076 - val_loss: 0.0877 - val_dice_coef: 0.6916
# Epoch 606/1000
# 4/4 [==============================] - 1s 296ms/step - loss: 0.0806 - dice_coef: 0.7051 - val_loss: 0.0875 - val_dice_coef: 0.6988
# Epoch 607/1000
# 4/4 [==============================] - 1s 292ms/step - loss: 0.0882 - dice_coef: 0.7057 - val_loss: 0.0872 - val_dice_coef: 0.6964
# Epoch 608/1000
# 4/4 [==============================] - 1s 294ms/step - loss: 0.0824 - dice_coef: 0.7066 - val_loss: 0.0880 - val_dice_coef: 0.6989
# Epoch 609/1000
# 4/4 [==============================] - 1s 294ms/step - loss: 0.0856 - dice_coef: 0.7050 - val_loss: 0.0867 - val_dice_coef: 0.6992
# Epoch 610/1000
# 4/4 [==============================] - 1s 290ms/step - loss: 0.0814 - dice_coef: 0.7074 - val_loss: 0.0887 - val_dice_coef: 0.7055
# Epoch 611/1000
# 4/4 [==============================] - 1s 291ms/step - loss: 0.0832 - dice_coef: 0.7083 - val_loss: 0.0896 - val_dice_coef: 0.7037
# Epoch 612/1000
# 4/4 [==============================] - 1s 292ms/step - loss: 0.0924 - dice_coef: 0.7126 - val_loss: 0.0883 - val_dice_coef: 0.6996
# Epoch 613/1000
# 4/4 [==============================] - 1s 295ms/step - loss: 0.0908 - dice_coef: 0.7074 - val_loss: 0.0882 - val_dice_coef: 0.7047
# Epoch 614/1000
# 4/4 [==============================] - 1s 297ms/step - loss: 0.0824 - dice_coef: 0.7089 - val_loss: 0.0879 - val_dice_coef: 0.7067
# Epoch 615/1000
# 4/4 [==============================] - 1s 298ms/step - loss: 0.0879 - dice_coef: 0.7110 - val_loss: 0.0865 - val_dice_coef: 0.7030
# Epoch 616/1000
# 4/4 [==============================] - 1s 294ms/step - loss: 0.0814 - dice_coef: 0.7074 - val_loss: 0.0872 - val_dice_coef: 0.6984
# Epoch 617/1000
# 4/4 [==============================] - 1s 291ms/step - loss: 0.0896 - dice_coef: 0.7086 - val_loss: 0.0921 - val_dice_coef: 0.6960
# Epoch 618/1000
# 4/4 [==============================] - 1s 296ms/step - loss: 0.0810 - dice_coef: 0.7088 - val_loss: 0.0873 - val_dice_coef: 0.7019
# Epoch 619/1000
# 4/4 [==============================] - 1s 292ms/step - loss: 0.0847 - dice_coef: 0.7087 - val_loss: 0.0866 - val_dice_coef: 0.7054
# Epoch 620/1000
# 4/4 [==============================] - 1s 289ms/step - loss: 0.0878 - dice_coef: 0.7089 - val_loss: 0.0866 - val_dice_coef: 0.6952
# Epoch 621/1000
# 4/4 [==============================] - 1s 287ms/step - loss: 0.0826 - dice_coef: 0.7057 - val_loss: 0.0872 - val_dice_coef: 0.6901
# Epoch 622/1000
# 4/4 [==============================] - 1s 286ms/step - loss: 0.0911 - dice_coef: 0.7071 - val_loss: 0.0871 - val_dice_coef: 0.6959
# Epoch 623/1000
# 4/4 [==============================] - 1s 287ms/step - loss: 0.0842 - dice_coef: 0.7131 - val_loss: 0.0878 - val_dice_coef: 0.6909
# Epoch 624/1000
# 4/4 [==============================] - 1s 286ms/step - loss: 0.0833 - dice_coef: 0.7075 - val_loss: 0.0879 - val_dice_coef: 0.6914
# Epoch 625/1000
# 4/4 [==============================] - 1s 291ms/step - loss: 0.0827 - dice_coef: 0.7099 - val_loss: 0.0880 - val_dice_coef: 0.6985
# Epoch 626/1000
# 4/4 [==============================] - 1s 287ms/step - loss: 0.0890 - dice_coef: 0.7113 - val_loss: 0.0890 - val_dice_coef: 0.7024
# Epoch 627/1000
# 4/4 [==============================] - 1s 282ms/step - loss: 0.0820 - dice_coef: 0.7080 - val_loss: 0.0878 - val_dice_coef: 0.6925
# Epoch 628/1000
# 4/4 [==============================] - 1s 288ms/step - loss: 0.0900 - dice_coef: 0.7087 - val_loss: 0.0879 - val_dice_coef: 0.7021
# Epoch 629/1000
# 4/4 [==============================] - 1s 295ms/step - loss: 0.0869 - dice_coef: 0.7096 - val_loss: 0.0872 - val_dice_coef: 0.7010
# Epoch 630/1000
# 4/4 [==============================] - 1s 291ms/step - loss: 0.0869 - dice_coef: 0.7035 - val_loss: 0.0874 - val_dice_coef: 0.6952
# Epoch 631/1000
# 4/4 [==============================] - 1s 286ms/step - loss: 0.0871 - dice_coef: 0.7136 - val_loss: 0.0885 - val_dice_coef: 0.6968
# Epoch 632/1000
# 4/4 [==============================] - 1s 292ms/step - loss: 0.0904 - dice_coef: 0.7120 - val_loss: 0.0879 - val_dice_coef: 0.6788
# Epoch 633/1000
# 4/4 [==============================] - 1s 294ms/step - loss: 0.0847 - dice_coef: 0.7058 - val_loss: 0.0893 - val_dice_coef: 0.7118
# Epoch 634/1000
# 4/4 [==============================] - 1s 288ms/step - loss: 0.0847 - dice_coef: 0.7137 - val_loss: 0.0889 - val_dice_coef: 0.6849
# Epoch 635/1000
# 4/4 [==============================] - 1s 284ms/step - loss: 0.0848 - dice_coef: 0.7026 - val_loss: 0.0900 - val_dice_coef: 0.6714
# Epoch 636/1000
# 4/4 [==============================] - 1s 286ms/step - loss: 0.0814 - dice_coef: 0.7063 - val_loss: 0.0878 - val_dice_coef: 0.6966
# Epoch 637/1000
# 4/4 [==============================] - 1s 295ms/step - loss: 0.0910 - dice_coef: 0.7100 - val_loss: 0.0883 - val_dice_coef: 0.6887
# Epoch 638/1000
# 4/4 [==============================] - 1s 290ms/step - loss: 0.0889 - dice_coef: 0.7082 - val_loss: 0.0909 - val_dice_coef: 0.6812
# Epoch 639/1000
# 4/4 [==============================] - 1s 287ms/step - loss: 0.0830 - dice_coef: 0.7073 - val_loss: 0.0898 - val_dice_coef: 0.6807
# Epoch 640/1000
# 4/4 [==============================] - 1s 287ms/step - loss: 0.0818 - dice_coef: 0.7080 - val_loss: 0.0909 - val_dice_coef: 0.6854
# Epoch 641/1000
# 4/4 [==============================] - 1s 291ms/step - loss: 0.0855 - dice_coef: 0.7079 - val_loss: 0.0896 - val_dice_coef: 0.6955
# Epoch 642/1000
# 4/4 [==============================] - 1s 292ms/step - loss: 0.0910 - dice_coef: 0.7075 - val_loss: 0.0894 - val_dice_coef: 0.7054
# Epoch 643/1000
# 4/4 [==============================] - 1s 292ms/step - loss: 0.0863 - dice_coef: 0.7123 - val_loss: 0.0889 - val_dice_coef: 0.6962
# Epoch 644/1000
# 4/4 [==============================] - 1s 288ms/step - loss: 0.0841 - dice_coef: 0.7105 - val_loss: 0.0892 - val_dice_coef: 0.6909
# Epoch 645/1000
# 4/4 [==============================] - 1s 287ms/step - loss: 0.0836 - dice_coef: 0.7116 - val_loss: 0.0874 - val_dice_coef: 0.7032
# Epoch 646/1000
# 4/4 [==============================] - 1s 289ms/step - loss: 0.0859 - dice_coef: 0.7076 - val_loss: 0.0867 - val_dice_coef: 0.6968
# Epoch 647/1000
# 4/4 [==============================] - 1s 289ms/step - loss: 0.0808 - dice_coef: 0.7061 - val_loss: 0.0868 - val_dice_coef: 0.6915
# Epoch 648/1000
# 4/4 [==============================] - 1s 288ms/step - loss: 0.0827 - dice_coef: 0.7082 - val_loss: 0.0884 - val_dice_coef: 0.6923
# Epoch 649/1000
# 4/4 [==============================] - 1s 292ms/step - loss: 0.0875 - dice_coef: 0.7125 - val_loss: 0.0874 - val_dice_coef: 0.7005
# Epoch 650/1000
# 4/4 [==============================] - 1s 292ms/step - loss: 0.0883 - dice_coef: 0.7088 - val_loss: 0.0876 - val_dice_coef: 0.6921
# Epoch 651/1000
# 4/4 [==============================] - 1s 290ms/step - loss: 0.0898 - dice_coef: 0.7081 - val_loss: 0.0873 - val_dice_coef: 0.7081
# Epoch 652/1000
# 4/4 [==============================] - 1s 294ms/step - loss: 0.0854 - dice_coef: 0.7124 - val_loss: 0.0882 - val_dice_coef: 0.7062
# Epoch 653/1000
# 4/4 [==============================] - 1s 290ms/step - loss: 0.0848 - dice_coef: 0.7117 - val_loss: 0.0905 - val_dice_coef: 0.6988
# Epoch 654/1000
# 4/4 [==============================] - 1s 291ms/step - loss: 0.0812 - dice_coef: 0.7093 - val_loss: 0.0877 - val_dice_coef: 0.7047
# Epoch 655/1000
# 4/4 [==============================] - 1s 294ms/step - loss: 0.0813 - dice_coef: 0.7113 - val_loss: 0.0874 - val_dice_coef: 0.6920
# Epoch 656/1000
# 4/4 [==============================] - 1s 290ms/step - loss: 0.0821 - dice_coef: 0.7069 - val_loss: 0.0870 - val_dice_coef: 0.6945
# Epoch 657/1000
# 4/4 [==============================] - 1s 289ms/step - loss: 0.0850 - dice_coef: 0.7054 - val_loss: 0.0879 - val_dice_coef: 0.6916
# Epoch 658/1000
# 4/4 [==============================] - 1s 294ms/step - loss: 0.0840 - dice_coef: 0.7103 - val_loss: 0.0876 - val_dice_coef: 0.6986
# Epoch 659/1000
# 4/4 [==============================] - 1s 303ms/step - loss: 0.0847 - dice_coef: 0.7126 - val_loss: 0.0887 - val_dice_coef: 0.6858
# Epoch 660/1000
# 4/4 [==============================] - 1s 292ms/step - loss: 0.0764 - dice_coef: 0.7074 - val_loss: 0.0890 - val_dice_coef: 0.6874
# Epoch 661/1000
# 4/4 [==============================] - 1s 297ms/step - loss: 0.0803 - dice_coef: 0.7126 - val_loss: 0.0895 - val_dice_coef: 0.6771
# Epoch 662/1000
# 4/4 [==============================] - 1s 298ms/step - loss: 0.0859 - dice_coef: 0.7135 - val_loss: 0.0887 - val_dice_coef: 0.6820
# Epoch 663/1000
# 4/4 [==============================] - 1s 295ms/step - loss: 0.0812 - dice_coef: 0.7129 - val_loss: 0.0911 - val_dice_coef: 0.6737
# Epoch 664/1000
# 4/4 [==============================] - 1s 294ms/step - loss: 0.0867 - dice_coef: 0.7118 - val_loss: 0.0899 - val_dice_coef: 0.6753
# Epoch 665/1000
# 4/4 [==============================] - 1s 294ms/step - loss: 0.0819 - dice_coef: 0.7105 - val_loss: 0.0866 - val_dice_coef: 0.6892
# Epoch 666/1000
# 4/4 [==============================] - 1s 292ms/step - loss: 0.0849 - dice_coef: 0.7114 - val_loss: 0.0881 - val_dice_coef: 0.6883
# Epoch 667/1000
# 4/4 [==============================] - 1s 297ms/step - loss: 0.0756 - dice_coef: 0.7105 - val_loss: 0.0896 - val_dice_coef: 0.6958
# Epoch 668/1000
# 4/4 [==============================] - 1s 288ms/step - loss: 0.0838 - dice_coef: 0.7147 - val_loss: 0.0878 - val_dice_coef: 0.6932
# Epoch 669/1000
# 4/4 [==============================] - 1s 290ms/step - loss: 0.0882 - dice_coef: 0.7125 - val_loss: 0.0873 - val_dice_coef: 0.6953
# Epoch 670/1000
# 4/4 [==============================] - 1s 295ms/step - loss: 0.0869 - dice_coef: 0.7123 - val_loss: 0.0894 - val_dice_coef: 0.6925
# Epoch 671/1000
# 4/4 [==============================] - 1s 291ms/step - loss: 0.0802 - dice_coef: 0.7088 - val_loss: 0.0880 - val_dice_coef: 0.6935
# Epoch 672/1000
# 4/4 [==============================] - 1s 288ms/step - loss: 0.0834 - dice_coef: 0.7123 - val_loss: 0.0875 - val_dice_coef: 0.6995
# Epoch 673/1000
# 4/4 [==============================] - 1s 288ms/step - loss: 0.0823 - dice_coef: 0.7159 - val_loss: 0.0871 - val_dice_coef: 0.7005
# Epoch 674/1000
# 4/4 [==============================] - 1s 291ms/step - loss: 0.0812 - dice_coef: 0.7137 - val_loss: 0.0889 - val_dice_coef: 0.6874

# %% [markdown]
# #### Evaluate

# %%
history = logs.history
plt.plot(history['loss'])
plt.plot(history['val_loss'])
plt.title('loss')
plt.show()
plt.plot(history['dice_coef'])
plt.plot(history['val_dice_coef'])
plt.title('Dice')
plt.show()

# %%
model_final = models.load_model('seg.h5', compile=False)

# %%
# Sample 1 batch
batch_idx = np.random.randint(len(val_gen))
print(batch_idx)
data = val_gen[batch_idx]
imgs, mask = data # (bs, 512, 512, 3), (bs, 512, 512, 1)
mask_pred = model_final.predict(imgs)

# show inputs
img_idx = np.random.randint(len(imgs)) # sample 1 image from batch
plt.figure(figsize=(20, 5))
plt.subplot(1,3,1)
plt.imshow(imgs[img_idx])

# show ground truth & model prediction
plt.subplot(1, 3, 2)
plt.imshow(mask[img_idx, :, :, 0])
plt.subplot(1, 3, 3)
plt.imshow(mask_pred[img_idx, :, :, 0])
plt.show()
# plt.imshow(mask_pred[img_idx, :, :, 0], cmap='gray')
# Out:
# 0

# %%
# Displayed with different threshold
mask_pred_raw = mask_pred[img_idx, :, :, 0]
mask_pred_raw
# Out:
# array([[0.00105908, 0.00122375, 0.00076911, ..., 0.00072052, 0.00062073,
#         0.00062025],
#        [0.00059524, 0.00053296, 0.00024053, ..., 0.00019409, 0.00030244,
#         0.00042141],
#        [0.00039623, 0.00030497, 0.00014046, ..., 0.00010725, 0.00015313,
#         0.00038697],
#        ...,
#        [0.00056065, 0.00030704, 0.00018644, ..., 0.00023927, 0.0002193 ,
#         0.00045215],
#        [0.00066985, 0.00043495, 0.00021543, ..., 0.00032298, 0.00038129,
#         0.00112824],
#        [0.00046657, 0.00061242, 0.00035081, ..., 0.00035057, 0.00059077,
#         0.00141758]], dtype=float32)

# %%
plt.imshow(mask[img_idx, :, :, 0])
plt.title('Ground Truth')
plt.show()

plt.figure(figsize=(20, 10))
for i in range(1, 10):
    plt.subplot(2, 5, i)
    threshold = i * 0.1
    mask_threshold = mask_pred_raw.copy()
    mask_threshold[mask_threshold <= threshold] = 0.
    mask_threshold[mask_threshold > threshold] = 1.
    plt.imshow(mask_threshold)
    plt.title(f'threshold: {threshold:.1f}')
plt.show()

# %%
# make prediction
threshold = 0.5
outputs = []
for i in range(len(test_gen)):
    x_test = test_gen[i]
    y_preds = model_final.predict(x_test)
    y_preds[y_preds <= threshold] = 0
    y_preds[y_preds > threshold] = 1
    for y_pred in y_preds:
        dots = np.where(y_pred.flatten() == 1)[0]
        run_lengths = []
        prev = -2
        for b in dots:
            if (b > prev +1):
                run_lengths.extend((b+1,0))
            run_lengths[-1] += 1
            prev = b
        output = ' '.join([str(r) for r in run_lengths])
        outputs.append(output)

# %%
df = pd.DataFrame(columns=['Id', 'Predicted'])
df['Id'] = [str(i) for i in range(20)]
df['Predicted'] = outputs
df.to_csv('submission.csv', index=None)
df
# Out:
#     Id                                          Predicted
# 0    0  15594 1 15621 3 15652 2 16106 1 16134 2 16164 ...
# 1    1  15103 3 15615 4 16128 5 16146 2 16640 7 16658 ...
# 2    2  15566 3 16078 3 16134 1 16590 3 16645 1 17102 ...
# 3    3  13559 3 14071 4 14584 4 15096 5 15609 4 16121 ...
# 4    4  16132 2 16643 2 17154 3 17187 4 17664 4 17699 ...
# 5    5  17188 3 17700 5 18213 5 18630 1 18726 6 19141 ...
# 6    6  16143 2 16615 3 16655 3 17123 10 17168 2 17636...
# 7    7  15080 1 15591 4 15635 1 16104 4 16145 4 16617 ...
# 8    8  15090 1 15126 5 15601 4 15635 7 16114 3 16146 ...
# 9    9  15616 1 16128 2 16640 2 17112 4 17152 3 17624 ...
# 10  10  16592 4 16602 6 17103 19 17614 19 18123 16 181...
# 11  11  15080 4 15591 4 15640 2 16103 4 16151 3 16615 ...
# 12  12  16136 2 16648 3 16669 2 17119 3 17161 3 17181 ...
# 13  13  13082 3 13594 3 14106 3 14619 3 15058 2 15131 ...
# 14  14  15624 2 16095 1 16135 3 16606 2 16647 2 16666 ...
# 15  15  15114 3 15626 5 16138 6 16652 5 16684 1 17165 ...
# 16  16  16609 1 17121 2 17633 2 17698 3 17705 1 18145 ...
# 17  17  15620 4 16130 7 16641 7 17152 5 17663 4 18174 ...
# 18  18  15618 2 16130 3 16642 4 17155 3 17668 2 17709 ...
# 19  19  17638 7 18152 9 18631 5 18669 8 18736 2 19142 ...
